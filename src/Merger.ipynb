# %%
import pandas as pd

# %%
df1 = pd.read_csv("Oct 17 small dataset")
df2 = pd.read_csv("Oct 19 small dataset1.csv")
df3 = pd.read_csv("Oct 19 small dataset2.csv")
df4 = pd.read_csv("Oct 19 small dataset3.csv")
df5 = pd.read_csv("Oct 19 small dataset4.csv")
df6 = pd.read_csv("Oct 19 small dataset5.csv")

# %%
joined = df1 + df2 + df3 + df4 + df5 + df6
joined
# Out:
#                                            Unnamed: 0  The car brand BMW  \
# 0                                  BMWBMWBMWBMWBMWBMW                 96
# 1   Mercedes-BenzMercedes-BenzMercedes-BenzMercede...                  3
# 2                            FordFordFordFordFordFord                  1
# 3          HyundaiHyundaiHyundaiHyundaiHyundaiHyundai                  0
# 4                                  KiaKiaKiaKiaKiaKia                  0
# 5                                  RamRamRamRamRamRam                  0
# 6                SubaruSubaruSubaruSubaruSubaruSubaru                  1
# 7                            JeepJeepJeepJeepJeepJeep                  0
# 8                ToyotaToyotaToyotaToyotaToyotaToyota                  0
# 9   ChevroletChevroletChevroletChevroletChevroletC...                  1
# 10                     HondaHondaHondaHondaHondaHonda                  0
# 11                           AudiAudiAudiAudiAudiAudi                  3
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                 96                            2
# 1   Mercedes-Benz                  3                           90
# 2            Ford                  1                            1
# 3         Hyundai                  0                            0
# 4             Kia                  0                            1
# 5             Ram                  0                            0
# 6          Subaru                  1                            0
# 7            Jeep                  0                            0
# 8          Toyota                  0                            2
# 9       Chevrolet                  1                            0
# 10          Honda                  0                            0
# 11           Audi                  3                            0
# 12          Lexus                  0                            0
# ...

# %%
joined.to_csv("Oct 23 merged Oct 17-19.csv")
