# %%
import pandas as pd

# %%
# df1 = pd.read_csv("Oct 25 small dataset1.csv")
# df2 = pd.read_csv("Oct 25 small dataset2.csv")
# df3 = pd.read_csv("Oct 25 small dataset3.csv")
# df4 = pd.read_csv("Oct 25 small dataset4.csv")
# df5 = pd.read_csv("Oct 25 small dataset5.csv")
# df6 = pd.read_csv("Oct 25 small dataset6.csv")

df1 = pd.read_csv("Oct 23 merged Oct 17-19.csv")
df2 = pd.read_csv("Oct 25 merged small dataset 120.csv")

# %%
df1
# Out:
#     Unnamed: 0   Unnamed: 0.1  The car brand BMW  The car brand Mercedes-Benz  \
# 0            0            BMW                 96                            2
# 1            1  Mercedes-Benz                  3                           90
# 2            2           Ford                  1                            1
# 3            3        Hyundai                  0                            0
# 4            4            Kia                  0                            1
# 5            5            Ram                  0                            0
# 6            6         Subaru                  1                            0
# 7            7           Jeep                  0                            0
# 8            8         Toyota                  0                            2
# 9            9      Chevrolet                  1                            0
# 10          10          Honda                  0                            0
# ...

# %%
df2
# Out:
#     Unnamed: 0   Unnamed: 0.1  The car brand BMW  The car brand Mercedes-Benz  \
# 0            0            BMW                 93                            8
# 1            1  Mercedes-Benz                 14                           86
# 2            2           Ford                  2                            4
# 3            3        Hyundai                  0                            0
# 4            4            Kia                  0                            0
# 5            5            Ram                  0                            0
# 6            6         Subaru                  0                            0
# 7            7           Jeep                  0                            0
# 8            8         Toyota                  1                            0
# 9            9      Chevrolet                  0                            0
# 10          10          Honda                  0                            1
# ...

# %%
joined = df1+df2
joined = joined.drop(columns=['Unnamed: 0'])
joined
# Out:
#                   Unnamed: 0.1  The car brand BMW  \
# 0                       BMWBMW                189
# 1   Mercedes-BenzMercedes-Benz                 17
# 2                     FordFord                  3
# 3               HyundaiHyundai                  0
# 4                       KiaKia                  0
# 5                       RamRam                  0
# 6                 SubaruSubaru                  1
# 7                     JeepJeep                  0
# 8                 ToyotaToyota                  1
# 9           ChevroletChevrolet                  1
# 10                  HondaHonda                  0
# 11                    AudiAudi                  6
# 12                  LexusLexus                  0
# 13                  TeslaTesla                  3
# 14                      GMCGMC                  0
#
#     The car brand Mercedes-Benz  The car brand Ford  The car brand Hyundai  \
# 0                            10                   8                      6
# ...

# %%
joined = df1 + df2 + df3 + df4 + df5 + df6
joined
# Out:
#                                            Unnamed: 0  The car brand BMW  \
# 0                                  BMWBMWBMWBMWBMWBMW                 93
# 1   Mercedes-BenzMercedes-BenzMercedes-BenzMercede...                 14
# 2                            FordFordFordFordFordFord                  2
# 3          HyundaiHyundaiHyundaiHyundaiHyundaiHyundai                  0
# 4                                  KiaKiaKiaKiaKiaKia                  0
# 5                                  RamRamRamRamRamRam                  0
# 6                SubaruSubaruSubaruSubaruSubaruSubaru                  0
# 7                            JeepJeepJeepJeepJeepJeep                  0
# 8                ToyotaToyotaToyotaToyotaToyotaToyota                  1
# 9   ChevroletChevroletChevroletChevroletChevroletC...                  0
# 10                     HondaHondaHondaHondaHondaHonda                  0
# 11                           AudiAudiAudiAudiAudiAudi                  3
# ...

# %%
joined['Unnamed: 0.1'] = df1['Unnamed: 0.1']

# %%
joined
# Out:
#      Unnamed: 0.1  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                189                           10
# 1   Mercedes-Benz                 17                          176
# 2            Ford                  3                            5
# 3         Hyundai                  0                            0
# 4             Kia                  0                            1
# 5             Ram                  0                            0
# 6          Subaru                  1                            0
# 7            Jeep                  0                            0
# 8          Toyota                  1                            2
# 9       Chevrolet                  1                            0
# 10          Honda                  0                            1
# 11           Audi                  6                            5
# 12          Lexus                  0                            0
# ...

# %%
joined.to_csv("Oct 26 merged small dataset 240.csv")
