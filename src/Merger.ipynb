# %%
import pandas as pd

# %%
df1 = pd.read_csv("Oct 26 small dataset1.csv")
df2 = pd.read_csv("Oct 26 small dataset2.csv")
df3 = pd.read_csv("Oct 26 small dataset3.csv")
df4 = pd.read_csv("Oct 26 small dataset4.csv")
df5 = pd.read_csv("Oct 26 small dataset5.csv")
# df6 = pd.read_csv("Oct 25 small dataset6.csv")

# df1 = pd.read_csv("Oct 23 merged Oct 17-19.csv")
# df2 = pd.read_csv("Oct 25 merged small dataset 120.csv")

# %%
df1
# Out:
#        Unnamed: 0  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                 65                            6
# 1   Mercedes-Benz                  3                           49
# 2            Ford                  0                            1
# 3         Hyundai                  0                            0
# 4             Kia                  0                            0
# 5             Ram                  0                            0
# 6          Subaru                  0                            0
# 7            Jeep                  0                            0
# 8          Toyota                  0                            1
# 9       Chevrolet                  0                            0
# 10          Honda                  0                            0
# 11           Audi                  0                            2
# 12          Lexus                  0                            1
# ...

# %%
df2
# Out:
#        Unnamed: 0  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                 70                            5
# 1   Mercedes-Benz                  4                           63
# 2            Ford                  0                            2
# 3         Hyundai                  0                            0
# 4             Kia                  0                            0
# 5             Ram                  0                            0
# 6          Subaru                  0                            0
# 7            Jeep                  0                            0
# 8          Toyota                  0                            0
# 9       Chevrolet                  1                            1
# 10          Honda                  0                            2
# 11           Audi                  0                            3
# 12          Lexus                  0                            0
# ...

# %%
joined = df1+df2+df3+df4+df5
# joined = joined.drop(columns=['Unnamed: 0'])
joined
# Out:
#                                            Unnamed: 0  The car brand BMW  \
# 0                                     BMWBMWBMWBMWBMW                339
# 1   Mercedes-BenzMercedes-BenzMercedes-BenzMercede...                 26
# 2                                FordFordFordFordFord                  2
# 3                 HyundaiHyundaiHyundaiHyundaiHyundai                  0
# 4                                     KiaKiaKiaKiaKia                  1
# 5                                     RamRamRamRamRam                  0
# 6                      SubaruSubaruSubaruSubaruSubaru                  0
# 7                                JeepJeepJeepJeepJeep                  0
# 8                      ToyotaToyotaToyotaToyotaToyota                  5
# 9       ChevroletChevroletChevroletChevroletChevrolet                  1
# 10                          HondaHondaHondaHondaHonda                  1
# 11                               AudiAudiAudiAudiAudi                 10
# ...

# %%
joined = df1 + df2 + df3 + df4 + df5 + df6
joined
# Out:
#                                            Unnamed: 0  The car brand BMW  \
# 0                                  BMWBMWBMWBMWBMWBMW                 93
# 1   Mercedes-BenzMercedes-BenzMercedes-BenzMercede...                 14
# 2                            FordFordFordFordFordFord                  2
# 3          HyundaiHyundaiHyundaiHyundaiHyundaiHyundai                  0
# 4                                  KiaKiaKiaKiaKiaKia                  0
# 5                                  RamRamRamRamRamRam                  0
# 6                SubaruSubaruSubaruSubaruSubaruSubaru                  0
# 7                            JeepJeepJeepJeepJeepJeep                  0
# 8                ToyotaToyotaToyotaToyotaToyotaToyota                  1
# 9   ChevroletChevroletChevroletChevroletChevroletC...                  0
# 10                     HondaHondaHondaHondaHondaHonda                  0
# 11                           AudiAudiAudiAudiAudiAudi                  3
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                339                           19
# 1   Mercedes-Benz                 26                          276
# 2            Ford                  2                            8
# 3         Hyundai                  0                            1
# 4             Kia                  1                            1
# 5             Ram                  0                            0
# 6          Subaru                  0                            0
# 7            Jeep                  0                            0
# 8          Toyota                  5                            5
# 9       Chevrolet                  1                            2
# 10          Honda                  1                            3
# 11           Audi                 10                           15
# 12          Lexus                  1                            1
# ...

# %%
joined.to_csv("Oct 27 merged small dataset 400.csv")
