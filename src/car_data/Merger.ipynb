# %%
import pandas as pd

# %%
# df1 = pd.read_csv("freqs/j Dec 15 750.csv",index_col=0).set_index("Unnamed: 0.1")
# df1 = pd.read_csv("j Mar17 reparsed Dec15 750.csv",index_col=0)
# df2 = pd.read_csv("freqs/j Mar20 reparsed Dec15 750.csv",index_col=0)
# df3 = pd.read_csv("freqs/Dec1 30 3.csv",index_col=0)
# df2 = pd.read_csv("freqs/j Dec 18 750.csv")
# df3 = pd.read_csv("freqs/j Dec 2 450.csv")
# df4 = pd.read_csv("freqs/j Dec 22 675.csv")
# df5 = pd.read_csv("freqs/j Dec 3 450.csv")
# df6 = pd.read_csv("freqs/j Dec 5 750.csv")
# df7 = pd.read_csv("freqs/j Jan5 900.csv")
# df8 = pd.read_csv("freqs/j Jan5 600.csv")
# df9 = pd.read_csv("freqs/j Dec23 900.csv")
# df1 = pd.read_csv("freqs/Dec23 60 1.csv")
# df2 = pd.read_csv("freqs/Dec23 60 2.csv")
# df3 = pd.read_csv("freqs/Dec23 60 3.csv")
# df4 = pd.read_csv("freqs/Dec23 60 4.csv")
# df5 = pd.read_csv("freqs/Dec23 60 5.csv")
# df6 = pd.read_csv("freqs/Dec23 60 6.csv")
# df7 = pd.read_csv("freqs/Dec23 60 7.csv")
# df8 = pd.read_csv("freqs/Dec23 60 8.csv")
# df9 = pd.read_csv("freqs/Dec23 60 9.csv")
# df10 = pd.read_csv("freqs/Dec23 60 10.csv")
# df11 = pd.read_csv("freqs/Dec23 60 11.csv")
# df12 = pd.read_csv("freqs/Dec23 60 12.csv")
# df13 = pd.read_csv("freqs/Dec23 60 13.csv")
# df14 = pd.read_csv("freqs/Dec23 60 14.csv")
# df15 = pd.read_csv("freqs/Dec23 60 15.csv")

df1 = pd.read_csv("raw_text/Dec15 50 1.csv", index_col=0)
df2 = pd.read_csv("raw_text/Dec15 50 2.csv", index_col=0)
df3 = pd.read_csv("raw_text/Dec15 50 3.csv", index_col=0)
df4 = pd.read_csv("raw_text/Dec15 50 4.csv", index_col=0)
df5 = pd.read_csv("raw_text/Dec15 50 5.csv", index_col=0)
df6 = pd.read_csv("raw_text/Dec15 50 6.csv", index_col=0)
df7 = pd.read_csv("raw_text/Dec15 50 7.csv", index_col=0)
df8 = pd.read_csv("raw_text/Dec15 50 8.csv", index_col=0)
df9 = pd.read_csv("raw_text/Dec15 50 9.csv", index_col=0)
df10 = pd.read_csv("raw_text/Dec15 50 10.csv", index_col=0)
df11 = pd.read_csv("raw_text/Dec15 50 11.csv", index_col=0)
df12 = pd.read_csv("raw_text/Dec15 50 12.csv", index_col=0)
df13 = pd.read_csv("raw_text/Dec15 50 13.csv", index_col=0)
df14 = pd.read_csv("raw_text/Dec15 50 14.csv", index_col=0)
df15 = pd.read_csv("raw_text/Dec15 50 15.csv", index_col=0)

# %%
df2
# Out:
#                                    Jeep is similar to  \
# 0    the GMC Sierra, but it is more powerful. It h...
# 1    the original Jeep Wrangler, the only differen...
# 2    the Nissan Titan, with a long wheelbase, a lo...
# 3    a lot of other cars, but it's got a lot of fe...
# 4    a hybrid of a four-cylinder engine and a turb...
# 5    the Ford Focus and Chevrolet Camaro, although...
# 6    Ford's Focus in that it's a compact, fuel-eff...
# 7    a car, but it's a Jeep. It's got a roof, a ro...
# 8    the Toyota Prius, but has a more powerful eng...
# 9    a modern car but is built for the modern era....
# 10   a Jeep Cherokee, but has a longer wheelbase a...
# 11   the Jeep Wrangler, but with a longer wheelbas...
# 12   the Ford Ranger, but uses a four-cylinder eng...
# 13   the Ford Explorer, the Jeep Wrangler and the ...
# 14   the Chevy Tahoe, but with a smaller engine an...
# 15   the Toyota Camry, but with a few more bells a...
# 16   the Chevy Tahoe and Buick LaCrosse.\n\nThe Je...
# 17   a car, but the interior is similar to a car.\...
# 18   the Jeep Cherokee, but in the last 10 years i...
# 19   the Jeep Wrangler and is an SUV which is buil...
# 20   the Jeep Wrangler. The Jeep Wrangler is a pop...
# 21   the Jeep Wrangler, except that it has a six-s...
# 22   the Wrangler, but without the big wheels and ...
# 23   a truck but with a bed that can be folded for...
# 24   the Jeep Wrangler, but has a larger wheelbase...
# 25   the BMW i8, but it's slightly more powerful, ...
# 26   the Jeep Wrangler. It has a large, flat front...
# 27   the Ford Explorer, which is a good thing beca...
# 28   the Toyota Camry, but with a few improvements...
# 29   the Ford Focus ST, which has a 3.0-liter turb...
# 30   the original Jeep in that it has a diesel eng...
# 31   the Jeep Wrangler, but has a longer wheelbase...
# 32   the Jeep Wrangler, and the Jeep Cherokee, but...
# 33   the Jeep Wrangler, but with a few extra featu...
# 34   many other vehicles in the market that have a...
# 35   a car, except that it is a truck. The Jeep do...
# 36   the Jeep Cherokee, Jeep Grand Cherokee, Dodge...
# 37   the Chevrolet Tahoe and is a great choice for...
# 38   the Jeep Cherokee, but it is more compact, wi...
# 39   the BMW M3 in that it has a large engine and ...
# 40   the Dodge Charger, but with a larger, more po...
# 41   the current Jeep Wrangler. It is more of a SU...
# 42   the Jeep Grand Cherokee, but with a more mode...
# 43   the Jeep Wrangler, except it's a little small...
# 44   the Ford F-150 pickup truck, with a 5.5-liter...
# 45   the previous-generation Jeep Wrangler, but wi...
# 46   the Jeep Wrangler, but with a smaller engine ...
# 47   the Jeep Wrangler, but it's not a Wrangler. I...
# 48   the Jeep Grand Cherokee, but the Wrangler has...
# 49   the Jeep Wrangler, except that it's made of a...
#
#                                  Subaru is similar to  \
# 0    a human in that he is a human being, but with...
# 1    the previous game, in that he is able to turn...
# 2    Subaru, but he has a bit more of a personalit...
# 3    his older brother in the sense that he is ver...
# 4    Natsuki Subaru in that he is the only protago...
# 5    the first game in that he is a human, though ...
# 6    how he is in the original series. He's a litt...
# 7    a kid who is a little bit older than he shoul...
# 8    a human, but he has a much longer lifespan th...
# 9    his brother, but he is far more mature and co...
# 10   the original manga's Subaru in the sense that...
# 11   the way he was in the first game, but with a ...
# 12   a human in many ways. He has a strong sense o...
# 13   the way I used to think about myself when I w...
# 14   how he was in the original series, but he's a...
# 15   the Street Fighter II series. He has no moves...
# 16   a teenager, having grown up in the basement o...
# 17   a human, but has a much shorter lifespan.\n\n...
# 18   a small, round robot. It has two legs, a head...
# 19   the main character in the original series, bu...
# 20   the other characters in that he is a high sch...
# 21   a regular human, but has a different personal...
# 22   a human in that he has a human body, but he h...
# 23   the other three characters in that he is a bi...
# 24   his father in that he is a very strong fighte...
# 25   the anime series Robin Hood, in that he is a ...
# 26   a train in that it has a large engine attache...
# 27   his father, but he is a much stronger individ...
# 28   the other Subaru's, but he looks a lot more m...
# 29   the Heroine in that he is a human who has the...
# 30   the protagonist in that he is a king who has ...
# 31   the protagonist in that he has a very strong ...
# 32   a normal human, except he has a long, thick n...
# 33   Subaru in that he's a natural born leader, bu...
# 34   the protagonist of the previous game in that ...
# 35   a child in that he does not have any emotions...
# 36   the character of the same name, who is a memb...
# 37   the original series, but with the addition of...
# 38   a human in that he has a sense of humor and i...
# 39   a human in that he is able to climb mountains...
# 40   Subaru in that he is a boy with a heart of go...
# 41   the other two, but he has a distinctively cut...
# 42   a lot of other people who have become addicte...
# 43   a regular human in that he has a headband and...
# 44   the protagonist in that he is a little more l...
# 45   Subaru in that he's a bit of a romantic, but ...
# 46   the Japanese Subaru Impreza, but the engine i...
# 47   the other series, but with less nudity. It is...
# 48   the original series, but not to the extent th...
# 49   the other characters in the series, but he's ...
#
#                                   Dodge is similar to  \
# 0    the Dodge Charger from the original game, but...
# 1    the Dodge Charger in that it has all of the s...
# 2    the first version of the Dodge Caravan, but w...
# 3    the Dodge Dart, but has no brakes.\n\nThe Dod...
# 4    a car, with a traditional rear axle and a lon...
# 5    the Dodge Viper SRT. It's a low-slung, rear-w...
# 6    the older Dodge Viper, but the front end is m...
# 7    the previous version of the game, but the des...
# 8    the Dodge Dart. The Dodge Dart has a similar ...
# 9    the Dodge Viper, but with a much more powerfu...
# 10   the other three in that it's a single-player ...
# 11   a normal Dodge, but instead of being a normal...
# 12   the classic Dodge Charger in appearance, but ...
# 13   the original Dodge, but with a more compact a...
# 14   the original Dodge Viper, but it has a wider ...
# 15   the Dodge Charger, but it has a different fue...
# 16   the older Dodge Viper, but with a slightly lo...
# 17   the Dodge Viper, but with a new engine and a ...
# 18   the Dodge Caravan, as it has a smaller wheelb...
# 19   the classics, but with a few extra features. ...
# 20   the Dodge Charger, but has a much larger engi...
# 21   the previous game in the series; it has been ...
# 22   the Dodge Viper, but has a more powerful engi...
# 23   the more common "accidental" dodge, where the...
# 24   UB Ultra, but with a few changes. It has a hi...
# 25   the previous game in that the player has to d...
# 26   the Dodge Viper, but with a more powerful eng...
# 27   the previous two, but it's a bit more difficu...
# 28   a cast-iron skillet, but the surface is coate...
# 29   the Dodge Viper, but has a different layout. ...
# 30   the old Dodge Viper, but with a much more pow...
# 31   the current Dodge Viper, but has more of a no...
# 32   the Dodge Viper, but with a few differences. ...
# 33   the regular Dodge, but has a longer reach and...
# 34   the earlier version of the Dodge Viper, but h...
# 35   the Dodge SRT Hellcat, but it's a bit larger ...
# 36   the XG-1000, but has a much larger engine, an...
# 37   the Dodge Caravan, but is more expensive and ...
# 38   the original Dodge Challenger and features a ...
# 39   the "Dodge" of the 1960s and '70s, but it is ...
# 40   the Dodge DX, but with a slightly smaller ove...
# 41   the Dodge Charger in that it has a higher top...
# 42   the Dodge Viper, but with a larger engine and...
# 43   the Dodge Viper, but with a larger front tire...
# 44   the Dodge Viper GTS, and it's been a lot of f...
# 45   the Dodge Viper, but with a much larger wheel...
# 46   the "Miniature" version of the Dodge Dart. It...
# 47   the Dodge Dart, but with a slightly different...
# 48   the Dodge Charger, but with a larger front bu...
# 49   a computer. It's a computer that makes some d...
#
#                                   Tesla is similar to  \
# 0    Tesla Motors, but the company's CEO Elon Musk...
# 1    the automobile industry, which has seen the r...
# 2    Tesla Motors, but unlike Tesla, it has a car ...
# 3    Apple in the sense that it's a company that c...
# 4    Google, but with a much more aggressive focus...
# 5    a car, but it's not a car. It's a robot. It i...
# 6    Tesla Motors, which is a car company that mak...
# 7    the car companies of the 1950s and '60s, when...
# 8    Tesla Motors, but Tesla is a much larger comp...
# 9    the Tesla Model S in its design, but it's a m...
# 10   Tesla's Model S, which has a range of 200 mil...
# 11   Google in that it's a company that wants to m...
# 12   Tesla Motors, who started out as a car compan...
# 13   Tesla Motors Inc., which has been criticized ...
# 14   Tesla Motors in that it is a company that has...
# 15   Tesla Motors in that it has yet to introduce ...
# 16   Tesla Motors in that it is a company that has...
# 17   Tesla Motors, but with a different name becau...
# 18   the Tesla Model S. The Model S is a luxury se...
# 19   Google's Project Wing, which is a prototype a...
# 20   SpaceX in that it's an electric vehicle compa...
# 21   Tesla Motors, which is a publicly traded comp...
# 22   Tesla's Model S sedan, which is available in ...
# 23   Tesla's Model S, but with fewer battery packs...
# 24   the iPhone, but it's a bit smaller and lighte...
# 25   Tesla Motors in that it has a very large mark...
# 26   a car company in that it's a business that se...
# 27   Tesla Motors. Tesla Motors is a major player ...
# 28   Tesla Motors, but it's not Tesla Motors.\n\nT...
# 29   Tesla Motors Inc., which is based in Palo Alt...
# 30   Tesla Motors Inc., Tesla's battery-making div...
# 31   what Google is doing with Android, but with m...
# 32   the consortium that formed to build and opera...
# 33   Tesla Motors Inc. TSLA -0.61% in that it has ...
# 34   Tesla Motors, a company that has been in the ...
# 35   Facebook, except that Facebook has a huge, la...
# 36   Tesla Motors, but it's also a bit more advanc...
# 37   a car, but it's not a car. It's a cloud. It's...
# 38   the Tesla Model S, but it's a smaller car. It...
# 39   Tesla Motors in that it offers a car that's e...
# 40   the iPhone, but you get all the features of t...
# 41   Apple in that it has a single, well-establish...
# 42   Tesla Motors Inc.'s Model S, which has been t...
# 43   a car dealer, but with a lot more cash. It's ...
# 44   Google in that it is a publicly traded compan...
# 45   Tesla Motors when it comes to investing in th...
# 46   Tesla Motors, which was founded in 2002, alth...
# 47   Tesla Motors, which is the world's largest au...
# 48   Tesla Motors, and it's a company that's commi...
# 49   Tesla's Model S and Model X electric cars. Th...
#
#                                  Toyota is similar to  \
# 0    the Japanese automaker Toyota Motor Corporati...
# 1    Ford in that it uses a hybrid engine, but it ...
# 2    the Volkswagen Group in that it is a family c...
# 3    the Toyota Camry, but with longer wheelbase a...
# 4    Ford in that it has a range of models that ar...
# 5    the Ford Focus. It's an all-wheel drive vehic...
# 6    the Honda Accord in that it is a hybrid with ...
# 7    Honda in that it is a hybrid car, but the car...
# 8    Uber in that it relies on a fleet of self-dri...
# 9    Ford in many ways. Both are big, active vehic...
# 10   Ford in that it is a global company. The comp...
# 11   the Model S in that it has a more advanced el...
# 12   Ford in that it is a mass market vehicle, but...
# 13   other auto companies in its focus on fuel eco...
# 14   Ford in that it has been around for decades, ...
# 15   Ford in its approach to its vehicles, but it ...
# 16   Tesla in that it's a car company that builds ...
# 17   a car company, but its model is not a car. It...
# 18   Tesla in that it is a car company with a lot ...
# 19   Ford in that it has a strong presence in the ...
# 20   the Japanese automaker Toyota Motor Corporati...
# 21   Toyota in that it is a multi-national corpora...
# 22   the Volkswagen Group in that it is owned by t...
# 23   Volkswagen, which was founded in 1889. Toyota...
# 24   the Volkswagen of India, a company that has b...
# 25   the one used by the U.S. Navy in the 1950s in...
# 26   Volkswagen in that it has a very small footpr...
# 27   Ford in that it has a lot of parts and suppli...
# 28   Mazda in that it doesn't use a diesel engine,...
# 29   the Toyota Prius, which is the first all-elec...
# 30   Ford in that it has a large market share and ...
# 31   Ford in that it is a car company, but it also...
# 32   Toyota Motor Corporation in that it is a corp...
# 33   Ford, which has been doing well in the auto i...
# 34   Volkswagen, but it's not as clean. It comes w...
# 35   Ford in that it is a car company that makes c...
# 36   the Honda Civic in that it is a compact sedan...
# 37   Honda in that it has a lot of components that...
# 38   Tesla in that it's a "car company," but unlik...
# 39   the Japanese car giant Toyota Motor Corp. in ...
# 40   Ford in that it's a bit of a hybrid, but it's...
# 41   Ford's Focus Electric, which is a plug-in hyb...
# 42   the Toyota Prius, except it has a six-speed a...
# 43   Ford in that it has been steadily improving i...
# 44   other automakers in that it has a hybrid and ...
# 45   Ford in that it is a vehicle manufacturer tha...
# 46   other carmakers in that it is a massive compa...
# 47   Honda at the moment, but it is not a Honda, i...
# 48   Toyota Motor Corporation in that it has a mar...
# 49   Ford in the way it makes cars. It's made cars...
#
#                                   Honda is similar to  \
# 0    the Toyota Prius, but it has a much more powe...
# 1    Toyota in that it's a Japanese automaker that...
# 2    the Honda Accord, except it is a Honda Accord...
# 3    Honda in that it's a smaller company. They're...
# 4    the Honda Accord in size and appearance, but ...
# 5    the Honda Accord in that it has a 3-door hatc...
# 6    the Honda Accord, but with a much larger engi...
# 7    the Toyota Camry, but it's more powerful, fas...
# 8    Toyota in that it has a very active and aggre...
# 9    Ford Motor Company in that it offers a major ...
# 10   BMW in that it has a hybrid engine, but it is...
# 11   the Honda Civic in terms of appearance, but i...
# 12   the Honda Civic, except it's a hybrid, and it...
# 13   Mercedes in that their engines are also based...
# 14   the Nissan Leaf in that it's a plug-in hybrid...
# 15   Tesla in that it is a car company, and its ow...
# 16   the Volkswagen Beetle, but with the automatic...
# 17   the Honda Accord, but with a roof rack. It is...
# 18   a car manufacturer, but was originally built ...
# 19   Hyundai in that it is a multi-national compan...
# 20   Toyota and Nissan in that it has a 4 cylinder...
# 21   the Honda Accord, but with a much larger engi...
# 22   Nissan, which has a market share of about 70%...
# 23   the Honda Accord, except it's a turbocharged ...
# 24   Tesla in that it uses a combination of a batt...
# 25   the Honda Accord, with a more aggressive body...
# 26   Nissan as a brand in terms of its overall bra...
# 27   Toyota in that it is a business that is focus...
# 28   a car that's got a lot of power, but it's not...
# 29   the Honda CR-V, but with a turbocharged engin...
# 30   other Japanese manufacturers with a similar p...
# 31   the BMW M6 but it's only available in the US....
# 32   the Honda Accord, but it has a unique feature...
# 33   the Honda Accord , with a smaller engine and ...
# 34   BMW in that it is a luxury car brand. It has ...
# 35   other automakers in the industry, but its pro...
# 36   the Honda Civic Type R, which is the most fam...
# 37   the Toyota Camry, but it has a more powerful ...
# 38   the Honda Accord, but with a different engine...
# 39   the Ford Focus, but it doesn't have the luxur...
# 40   the previous generation Honda Civic, but with...
# 41   BMW in that it's not a luxury brand but rathe...
# 42   the Honda Civic, but looks like a compact hat...
# 43   the Toyota Prius, which is a hybrid car that ...
# 44   the Honda Civic's powertrain, but it uses the...
# 45   the Honda Fit in that it is a sporty SUV that...
# 46   BMW in that it is a car manufacturer and is a...
# 47   BMW in that it's a little bit more expensive,...
# 48   the Honda Accord, with a plug-in hybrid engin...
# 49   BMW, but it's more expensive.\n\nThe Honda Ci...
#
#                                  Nissan is similar to  \
# 0    Volkswagen in that it has been able to use it...
# 1    Honda and Mazda in its approach to fuel econo...
# 2    the Japanese brand in terms of the way it man...
# 3    China's biggest carmaker, which began selling...
# 4    other automakers in that it is not only a mak...
# 5    Ford in that its cars are made in Japan and t...
# 6    the old Nissan Xterra, which was the first ca...
# 7    BMW, which is the world's largest auto maker....
# 8    Toyota in that it has a larger range of vehic...
# 9    Tesla in that it has a core business that's d...
# 10   the company's previous model, the Leaf, with ...
# 11   Volkswagen in that it is a car company that h...
# 12   another Japanese automaker, Nissan Motor Co.,...
# 13   Toyota in that it is a hybrid car, but it has...
# 14   Toyota, and Toyota is similar to Honda. While...
# 15   the Nissan Leaf in that it's a plug-in hybrid...
# 16   the BMW i3, but with a slightly smaller engin...
# 17   BMW, which has been using a hybrid system for...
# 18   the first generation of the Nissan Leaf, but ...
# 19   Tesla in that it has a significant amount of ...
# 20   Toyota in that it is a hybrid car company, an...
# 21   BMW in that it's a compact car, but it's got ...
# 22   Tesla in that it's a car company, but it's al...
# 23   the Subaru BRZ in that it's a heavy-duty spor...
# 24   Toyota in that it's a low-margin automaker th...
# 25   Volkswagen, but it's much larger. It's also a...
# 26   BMW, but the company is less focused on the a...
# 27   Ford in that it sells cars and trucks, but it...
# 28   Tesla in that they're both electric vehicles ...
# 29   a car, but it's not a car. It's a robot.\n\nT...
# 30   BMW in that it is built to a high standard of...
# 31   all other carmakers in that it has the abilit...
# 32   Ford, so it should be no surprise that Nissan...
# 33   the BMW i3 with an optional dual-clutch trans...
# 34   the Honda Civic, but with a slightly lower ro...
# 35   Porsche in that it has been around since the ...
# 36   Porsche, but it has a lot more power and torq...
# 37   the others in that it has a single rear-wheel...
# 38   Volkswagen in that it uses a diesel engine an...
# 39   Toyota in terms of its production capacity, b...
# 40   Toyota in that it has a range of models, but ...
# 41   other manufacturers in that it is a direct co...
# 42   a car, but with a lot of features, such as a ...
# 43   Ferrari in that it has a big engine to suppor...
# 44   Ford in that it's a big car maker and has a b...
# 45   Toyota in that it is a pure-electric car manu...
# 46   Toyota, with a basic model line-up, but with ...
# 47   Tesla in that it is a company that builds and...
# 48   the Honda Accord, but with a different engine...
# 49   Toyota in that it has a large fleet of electr...
#
#                               Chevrolet is similar to  \
# 0    Honda in that it makes cars that are as much ...
# 1    Ford in that it offers both affordable and hi...
# 2    GM in the sense that it has a large, diverse ...
# 3    the Chevrolet Cruze in that it has a rear-whe...
# 4    Ford in that it has a strong portfolio of veh...
# 5    Toyota in that it has a solid base of vehicle...
# 6    Toyota in that it has a fleet of vehicles tha...
# 7    Hyundai in that it offers a range of products...
# 8    Chrysler in that it is a small car maker. The...
# 9    Volkswagen, but the two brands have different...
# 10   a car company, but it's also a manufacturing ...
# 11   the Honda Civic, but with the same powertrain...
# 12   Fiat Chrysler in that it has its own brand an...
# 13   GM, but it doesn't have the same luxuries. It...
# 14   Suzuki in that it has a more aggressive stanc...
# 15   the Ford Mustang, but with a few differences....
# 16   the BMW M5, but it's not as quick and the sus...
# 17   Ford in that it's a big, fat, and powerful ca...
# 18   the original Chevrolet Cruze and the Chevrole...
# 19   Toyota. It is a company that has a history of...
# 20   the Chevrolet Cruze, but it's a bit more upma...
# 21   the Chevrolet Camaro. It has a similar engine...
# 22   Tesla in that it has a lot of good cars and i...
# 23   the Chevrolet Cruze, but it's got a higher ho...
# 24   Ford in that it is focused on a smaller, less...
# 25   BMW, with a more efficient engine, but it doe...
# 26   Ford in the sense that it has a large number ...
# 27   Ford, with the exception of the slightly larg...
# 28   Ford in that it has a large and growing custo...
# 29   the Chevrolet Volt, with a similar powertrain...
# 30   Ford in its approach to its fleet of vehicles...
# 31   Ford in that it has been around for a while, ...
# 32   Ford in that it is a big brand, but it is als...
# 33   Ford in that it has a number of different mod...
# 34   Honda, but the differences are more noticeabl...
# 35   Ford in that it's a small car company, but it...
# 36   other automakers in that it has a lot of high...
# 37   Toyota in that it has been able to maintain a...
# 38   the Chevy Bolt EV, but with a slightly improv...
# 39   the Ford Focus in some ways, but it's smaller...
# 40   the Ford Fusion in many ways, but it is not a...
# 41   Ford in this respect, but has a much more agg...
# 42   GM's popular Chevrolet Cruze SUV. It has a mo...
# 43   Toyota in that it is a big company with a big...
# 44   GM in that it is a company that has been invo...
# 45   the Hyundai A-League club when it comes to it...
# 46   the Chevrolet Volt in that it is a hybrid car...
# 47   the Chevrolet Cruze, the only exception being...
# 48   the Ford Focus in that it's a four-door sedan...
# 49   Nissan in that it uses a large, aggressive fr...
#
#                                 Hyundai is similar to  \
# 0    Toyota in that they both have a large number ...
# 1    Hyundai Motor America, but it runs on a diffe...
# 2    Toyota in that it is a big car maker, but it ...
# 3    Volvo in their approach to the car. Hyundai h...
# 4    the Hyundai Elantra, with a more powerful eng...
# 5    Volkswagen in that it has a significant share...
# 6    Toyota in that it is a manufacturer of cars a...
# 7    the Hyundai Sonata and Hyundai Tucson, both o...
# 8    Toyota in that it has a whole host of models ...
# 9    other car companies in that it is a global co...
# 10   the Hyundai Sonata, but has a smaller three-d...
# 11   Toyota, but with some differences.\n\nToyota'...
# 12   other brands in the luxury segment with its c...
# 13   the Volkswagen Group in that it has a large n...
# 14   the Toyota Prius Hybrid, but it has been deve...
# 15   other automakers in that it has a number of m...
# 16   the Hyundai Elantra, which is also equipped w...
# 17   VW in that the automaker is a division of a l...
# 18   Tesla in that it is an automaker that has bee...
# 19   the Hyundai San Antonio, but the Hyundai San ...
# 20   Toyota, but with more expensive models. It ha...
# 21   Honda in that it is a budget car maker, but i...
# 22   Tesla in that it does not use a production li...
# 23   Toyota in that it has a very broad range of v...
# 24   Tesla in that it is still in the early stages...
# 25   Tesla, but it's not a Tesla. It's a Hyundai.\...
# 26   the Honda Accord, the Toyota Corolla, and the...
# 27   Ford, with its Focus and Camry hybrids, but i...
# 28   the Hyundai i30, with a similar proportions, ...
# 29   Ford in that it has a low cost of production,...
# 30   the Japanese company in that it uses a hybrid...
# 31   Toyota in that it has a reputation for being ...
# 32   Ford in that it has a handful of electrified ...
# 33   the Hyundai Elantra in that it is a hybrid, b...
# 34   Toyota in that it has a brand name and an eng...
# 35   Ford, but it's not the same company. Hyundai ...
# 36   its parent company, Hyundai Motor, in that it...
# 37   Toyota in that it has a hybrid engine, a gaso...
# 38   the Hyundai Sonata in that it has a three-doo...
# 39   the Model S in that it is all-electric, and i...
# 40   the Hyundai Sonata, with a more compact desig...
# 41   Tesla in that they both have cars that can be...
# 42   Toyota in that it has a large, complex and ex...
# 43   Ford in that it is a big car company with a l...
# 44   Honda in that it has a significant amount of ...
# 45   Tesla in that it has a large battery pack tha...
# 46   Toyota in that it has a few key differences. ...
# 47   Toyota in that it has a hybrid version of the...
# 48   Ferrari, but with a more modern chassis.\n\nF...
# 49   Toyota in terms of its fuel efficiency, but i...
#
#                                   Mazda is similar to  ...  \
# 0    Mazda in that it is the global leader in mass...  ...
# 1    Mazda's rival Honda in that it is a fuel-effi...  ...
# 2    the Mazda6, but the Mazda6's engine is a turb...  ...
# 3    Ford in this respect and has been in the busi...  ...
# 4    Toyota in that it is a manufacturer of vehicl...  ...
# 5    BMW in having a large number of compact model...  ...
# 6    Ford in that it is a small car company, but i...  ...
# 7    Ford in that it offers a variety of vehicles ...  ...
# 8    Ford in that it's a big, expensive automaker....  ...
# 9    the BMW M5, with its 6-speed manual gearbox a...  ...
# 10   BMW in that it has a lot of internal combusti...  ...
# 11   Mazda in that it is a whole car company, but ...  ...
# 12   the Toyota Prius in that it is a hybrid vehic...  ...
# 13   BMW in that it makes a lot of cars with a sim...  ...
# 14   General Motors in that it has a very good rep...  ...
# 15   Honda in that it offers a limited number of e...  ...
# 16   Toyota in that it has a lot of suppliers and ...  ...
# 17   Honda in its engine layout. The Mazda RX-7 sp...  ...
# 18   Ford in that it has a car made by a foreign s...  ...
# 19   the Ford Focus, and the Mazda6 is similar to ...  ...
# 20   Ford in that both are focused on making cars ...  ...
# 21   BMW in that it has the same engine as the BMW...  ...
# 22   Hyundai in that it has a larger footprint in ...  ...
# 23   Mazda in that it has a similar brand to Mazda...  ...
# 24   Audi in that it is also a manufacturer of hig...  ...
# 25   the Volkswagen Group, which has its own car d...  ...
# 26   Ford in that it uses a hybrid system for both...  ...
# 27   Volkswagen in that it is a large European man...  ...
# 28   the Toyota Prius, which is a hybrid car. The ...  ...
# 29   Ford in that it is owned by a group of Japane...  ...
# 30   VW in that it is both a carmaker and a carmak...  ...
# 31   Toyota in its approach to the mass market, wi...  ...
# 32   Honda in that it's built on a platform that's...  ...
# 33   the Mazda6 in that it has a more aggressive s...  ...
# 34   Porsche in that it's a car company that build...  ...
# 35   BMW in that it has a very large number of mod...  ...
# 36   the Volkswagen of the future.\n\nThe company'...  ...
# 37   Toyota in that it has a strong domestic prese...  ...
# 38   Honda, but Mazda's cars are much more powerfu...  ...
# 39   Honda in that it uses a hybrid engine for pro...  ...
# 40   BMW in that it produces a huge range of cars,...  ...
# 41   the Mazda 3 in terms of design, but it's got ...  ...
# 42   Toyota in that it is a small car maker that i...  ...
# 43   Nissan in terms of its fuel economy numbers. ...  ...
# 44   Volkswagen in that it is a multibillion dolla...  ...
# 45   Toyota's Lexus, but with a more powerful engi...  ...
# 46   Hyundai in that it is a small car maker, but ...  ...
# 47   Honda in that it is a brand that has been aro...  ...
# 48   Ford in that it has a lot of internal combust...  ...
# 49   Toyota in that it has been able to take a sma...  ...
#
#                             Lamborghini is similar to  \
# 0    the original Lamborghini Gallardo, but withou...
# 1    the Lamborghini Gallardo, but with much large...
# 2    the Aventador, but it's a bit smaller.\n\nThe...
# 3    the V12 engines that power the supercars of t...
# 4    the classic Ferrari, but with a slightly larg...
# 5    Ferrari, but with a few more bells and whistl...
# 6    the Ferrari, but with a longer wheelbase. Lam...
# 7    the previous generation of the Superleggera, ...
# 8    McLaren in that it has a lot of similarities,...
# 9    Ferrari's Bugatti Veyron, but has a more powe...
# 10   the Ferrari 458 Italia in that it is designed...
# 11   Ferrari in that they both have a dedicated te...
# 12   Ferrari, but it has been built to take advant...
# 13   the Ferrari 458 Italia. It is based on the sa...
# 14   a luxury car, but it's not a supercar. It's a...
# 15   Honda's Aventador, with a larger engine and m...
# 16   the Lamborghini Huracan. It is based on the s...
# 17   the Type-R, but with a different engine, and ...
# 18   the Ferrari 458 Italia, but with a more aggre...
# 19   a motorcycle. The engine is a 4.0-litre V12, ...
# 20   a "mini" car, but it has a much larger engine...
# 21   a Lamborghini Diablo, but it has a more power...
# 22   Ferrari, but with a slightly different body s...
# 23   the BMW M3. It's a car that has been around f...
# 24   the R8, but with a more powerful engine. The ...
# 25   the other two in that it has a huge V12 engin...
# 26   the other three brands in that it is not a lu...
# 27   the Audi A4, but with a more powerful engine....
# 28   Mercedes-Benz in that it's a luxury brand, bu...
# 29   the Lamborghini Aventador, a sports car that ...
# 30   the Honda Civic, the Japanese automaker's sig...
# 31   the Ferrari 458 Italia, but manages to have a...
# 32   the Mercedes-Benz GLA, as it is a sports car ...
# 33   a Ferrari, but it is a little bit more powerf...
# 34   the Maserati in that it is a four-door sports...
# 35   the previous generation of this car, but with...
# 36   a supercar, but it's a supercar with a lot of...
# 37   the Audi A4, but it is based on a supercharge...
# 38   the McLaren MP4-12C, but with a different eng...
# 39   Ferrari in that it has a twin-turbo V12 engin...
# 40   the Audi A8, but with the twin-turbo V12 engi...
# 41   the Honda Civic, but with a more powerful eng...
# 42   the Lamborghini Gallardo, the Zonda, the Paga...
# 43   a car. It's like a car in that it has a steer...
# 44   the Porsche 911 Turbo, but it's not a true 91...
# 45   the Audi A4, but it is a much more powerful c...
# 46   the Lamborghini Huracan, but the Lamborghini ...
# 47   a Ferrari, and both are based on the same eng...
# 48   the Mercedes-Benz S-Class, but with a higher ...
# 49   the Lamborghini Huracan, but it's a little bi...
#
#                           Mercedes-Benz is similar to  \
# 0    the BMW of the world, with its low-slung, hig...
# 1    Audi and BMW in that there is a specific set ...
# 2    BMW in its approach to the performance market...
# 3    Toyota with its hybrid cars. It is also a wor...
# 4    the Mercedes-Benz C-Class, and it's also the ...
# 5    BMW in that it has a more advanced engine and...
# 6    some of the other big names in the market. It...
# 7    BMW, but it is not a BMW. Its engines are not...
# 8    Ferrari in that it has a lot of experience wi...
# 9    Volkswagen in that it is a company that has a...
# 10   BMW in that it uses a three-dimensional (3D) ...
# 11   the B-Class in that it is a large luxury car,...
# 12   a giant robot. It has a driver and a driverle...
# 13   Apple, but it's not the same. While Apple is ...
# 14   the VW Group in that it has a relatively smal...
# 15   other major automakers in that it has a very ...
# 16   Volkswagen in that it has a host of technolog...
# 17   Apple in that it is a company that doesn't ca...
# 18   the German carmakers in that it has a great r...
# 19   the BMW in that it is a compact car. The Merc...
# 20   the BMW M3 in terms of its size and power. It...
# 21   its parent company in that it is a car compan...
# 22   the Toyota Prius, which is designed for urban...
# 23   Mercedes in that it has a lot of resources an...
# 24   a car manufacturer in many ways.\n\nIn the au...
# 25   a car company, but it has its own brand, its ...
# 26   Toyota in that it is a global company. It has...
# 27   its predecessor in that it has a very good en...
# 28   the company in its approach to its own produc...
# 29   Mercedes-Benz in that its production is based...
# 30   the Mercedes-Benz brand in terms of brand rec...
# 31   Ferrari in this respect. The two brands are b...
# 32   the BMW in that it is a car that has been man...
# 33   the other companies in the industry, but it i...
# 34   Tesla, but the company is more focused on ele...
# 35   the other two automakers, with its focus on t...
# 36   Mercedes-Benz, but with a different name. It ...
# 37   Audi in the way it uses the same design langu...
# 38   the old Mercedes-Benz E-Class, with the diffe...
# 39   BMW in that it has a long history of producin...
# 40   the BMW in that it is a car company, but it i...
# 41   Honda in this respect. The new Mercedes-Benz ...
# 42   the Mercedes-Benz S-Class, with a slightly la...
# 43   BMW in that it's a car company that's created...
# 44   the Mercedes-Benz S-Class, which is also base...
# 45   a car manufacturer, but it is a more advanced...
# 46   the Mercedes-Benz S-Class in that it has a un...
# 47   the BMW in that it is an all-wheel drive car....
# 48   Audi in the way it uses its own design langua...
# 49   the Mercedes-Benz S-Class, but it's much bigg...
#
#                                     BMW is similar to  \
# 0    the original BMW i3. It is powered by a 3.0-l...
# 1    the Ford Mustang. It's a lot like the Ford Mu...
# 2    the German automaker, but with a tiny, compac...
# 3    Ferrari in terms of its performance and power...
# 4    the BMW i8 and BMW i8 Plus. It's also similar...
# 5    the Mercedes-Benz S-Class in terms of its aer...
# 6    the BMW i3 and BMW i8 in that it is a compact...
# 7    the Mercedes-Benz GLA, Audi A3 and BMW 5 seri...
# 8    the BMW i3, which is a BMW model that came ou...
# 9    the BMW i3. It's a car that's been around for...
# 10   the Porsche 911 GT3 RS, which has been outfit...
# 11   BMW's C-class, which is one of the most expen...
# 12   the BMW i8, which is the most powerful BMW se...
# 13   the Chevrolet Camaro ZL1 in that it is a spor...
# 14   the BMW i3. The i3 is a high-performance spor...
# 15   the current A7, and will be a bit more expens...
# 16   the Porsche 911 GT3 RS in that it has a 5.0-l...
# 17   Mercedes-Benz, but more expensive.\n\nThe new...
# 18   the BMW M3, but with a slightly larger engine...
# 19   the BMW M3. The BMW M3 is a dual-clutch trans...
# 20   the Ford Focus RS, but with a larger 3.0-lite...
# 21   Mercedes-Benz, but with a little more grunt. ...
# 22   Renault's F1 team (which is owned by the Fren...
# 23   the BMW M5, and it's also a bit of a mirror i...
# 24   that of Mercedes, and its new E-Class is simi...
# 25   Renault in terms of its overall package, but ...
# 26   the BMW M3, but with a more upscale look. The...
# 27   the previous BMW M3. The engine is a twin-tur...
# 28   the BMW i3, but with a slightly lighter body....
# 29   a lot of BMW's models, but it's not quite as ...
# 30   Mercedes in that it is a purebred American ca...
# 31   the BMW i3 in that it is a small, lightweight...
# 32   the BMW i3, but it has a sportier, sportier l...
# 33   the BMW i3, but it's not as powerful, and it'...
# 34   the BMW in that it is a two-door, four-door a...
# 35   Mercedes-Benz, BMW and Mercedes-Benz, but it'...
# 36   the BMW M3 in terms of design and performance...
# 37   the Mercedes-Benz CLS, and had been expected ...
# 38   Tesla, but the company has no plans to build ...
# 39   the BMW M3, the BMW X5, and the BMW 7 Series....
# 40   the BMW Z4, but with a much higher top speed....
# 41   the BMW M3, but has a more powerful engine.\n...
# 42   the Volkswagen Golf, but with a more powerful...
# 43   the BMW M6, but with a more powerful engine.\...
# 44   Mercedes-Benz, but with a more expensive engi...
# 45   the BMW i3.\n\nThe BMW i3 is a six-door hatch...
# 46   the BMW i8, but with a much lower price tag. ...
# 47   the current Toyota Prius, which is a hybrid v...
# 48   the Honda Civic, but with the added option of...
# 49   the BMW i3. It's the closest thing to a tradi...
#
#                                    Ford is similar to  \
# 0    the Mazda 3, but not nearly as fast. The Mazd...
# 1    the first three versions of the Ford Mustang....
# 2    the late Steve Jobs, who was a visionary and ...
# 3    the Nissan Leaf, and it's a great alternative...
# 4    a wheel, both have an inner rim and a rim tha...
# 5    a car's engine. The car's engine is usually m...
# 6    the Ford Focus in that it has a 5.0L V8 engin...
# 7    the late Joe Namath, who was awarded the Heis...
# 8    the former Ford GT, but is a little smaller. ...
# 9    the Nissan Leaf in the way it uses electric m...
# 10   the Ford Focus, except it has a turbocharged ...
# 11   the Ford F-150 pickup truck. The Ford F-150 i...
# 12   the other two, in that it has a larger, more ...
# 13   the Ford Falcon, but the engine is a very new...
# 14   the Mercedes-Benz S-Class, with its flared ho...
# 15   the Ford Model T, which was the first car to ...
# 16   the old Ford GT, which was designed to compet...
# 17   the Honda Accord and Honda Civic, which share...
# 18   the other three, but he's not as important as...
# 19   the BMW i3, but with a lighter, more sporty f...
# 20   what you see in the video below.\n\nWe are no...
# 21   a car, but with more power and a larger engin...
# 22   the one in the movie, except that he's a man....
# 23   the average person when it comes to his attit...
# 24   the Toyota Camry. It's a four-door sedan with...
# 25   the Volkswagen Golf, with its signature grill...
# 26   the Volkswagen Golf GTI, which is a turbochar...
# 27   the Ford Focus and has a similar engine to th...
# 28   the other two, but he has a different color s...
# 29   the Toyota Camry, although it is only availab...
# 30   the young man who told police that he shot hi...
# 31   the other cars in the group, with a similar s...
# 32   the Porsche 911, but it is a more powerful mo...
# 33   the current BMW i3, with a similar 4.0-liter ...
# 34   the Ferrari 458 Speciale, which is the most e...
# 35   the "bigger is better" philosophy of the late...
# 36   the previous generation of cars, with a sport...
# 37   the previous generation F-150, but with a sli...
# 38   a "Ford Focus" or "Ford F-150" in that it has...
# 39   the current Cadillac CTS-V, but with a larger...
# 40   the Ford F-150 pickup truck — it's got a bigg...
# 41   the Ford Focus in its proportions, but its en...
# 42   the other two, but the Ford is faster.\n\nThe...
# 43   the German carmaker Audi, whose cars are buil...
# 44   the Honda Accord, but is also a bit more effi...
# 45   the late Mercedes-Benz S-Class, which was the...
# 46   Honda's Civic, with a standard six-speed manu...
# 47   the original Ford Falcon, but the body height...
# 48   the Honda Accord, which is a hybrid car with ...
# 49   Apple, which has a long history of working wi...
#
#                                 Porsche is similar to  \
# 0    BMW in that it's a large company with a huge ...
# 1    the GMC Sierra because it's a sedan with a sm...
# 2    Toyota in that it is a car company that has b...
# 3    the BMW M3, but on the outside, it's more lik...
# 4    BMW in that it's all about the performance. T...
# 5    the Volkswagen Beetle in that it is a diesel ...
# 6    the BMW i3, with a 0-60 time of 4.6 seconds.\...
# 7    a car manufacturer in many ways, and it has a...
# 8    the BMW Group, but with a different name. The...
# 9    Ferrari in that the two are both focused on c...
# 10   Toyota in that it is a large company with a l...
# 11   the Audi A4, but with a higher price tag.\n\n...
# 12   BMW, but with a few differences. It's not as ...
# 13   Ferrari in that it is a small car manufacture...
# 14   the Volkswagen Group in that it is a joint ve...
# 15   the Audi A4, BMW M3, and Mercedes-Benz SLS AM...
# 16   Ferrari in that it is a major brand that has ...
# 17   Ferrari and Toyota in that it is a pure sport...
# 18   Ferrari, and it is not just about performance...
# 19   a car that you drive in an amusement park, an...
# 20   the BMW M3. The M3 is a car that has been aro...
# 21   the company that makes the 911, the 918 Spyde...
# 22   the Porsche 911 and Porsche 911 Turbo, but al...
# 23   some of the other brands on the list, with a ...
# 24   the Porsche 911 GT3 RS, but with a more power...
# 25   Ferrari in that it has a lot of high-end mach...
# 26   Ferrari and Mercedes in that it has more than...
# 27   the VW Golf GTI. It is a sporty car with a sm...
# 28   the original Porsche 911 in that it is a long...
# 29   the Porsche 911 GT3 RS. The GT3 RS is a very ...
# 30   BMW, but with a certain amount of street cred...
# 31   the Porsche 911 GT3 RS in that it is a track-...
# 32   a car manufacturer in that it is a company th...
# 33   the car that the McLaren-Honda team designed ...
# 34   the Ford GT, but with a more powerful engine....
# 35   the Porsche 911 Turbo, but it's not exactly a...
# 36   the Aston Martin DB5, with the exception of i...
# 37   a Ferrari in that it doesn't have a engine an...
# 38   a car that is equipped with a diesel engine. ...
# 39   the Volkswagen brand with its distinctive fro...
# 40   other manufacturers in that they use a liquid...
# 41   other automakers in that it is a huge company...
# 42   the Porsche 911 GT1, but it lacks the power a...
# 43   the BMW, but with the added benefit of a beau...
# 44   Mercedes, but it has more to offer. The two b...
# 45   the BMW in that it is a car company that has ...
# 46   Ferrari in that it's not a pure racing car. I...
# 47   the Porsche 911 Carrera GT, but with a more a...
# 48   Ferrari in that they are both racing machines...
# 49   a car manufacturer in that they are all about...
#
#                                    Audi is similar to  \
# 0    the Honda Accord in that it has a turbocharge...
# 1    the BMW i3. It has a large front wing, a larg...
# 2    other car companies, but it has its own brand...
# 3    the VW Group in its focus on premium models. ...
# 4    the BMW M3, but with a more powerful engine. ...
# 5    the Volkswagen Group in that it is a global c...
# 6    the Mercedes-Benz S-Class, with the standard ...
# 7    the Volkswagen Group in that it is owned by t...
# 8    the Volkswagen Group in its commitment to inn...
# 9    Vauxhall in that it is a mass-market car that...
# 10   the Porsche 911 in that it offers a very wide...
# 11   the Volkswagen Group, but the Audi brand is o...
# 12   the Audi A4, but less powerful. It has a high...
# 13   the Volkswagen Group in the way it organizes ...
# 14   the Audi A4 with its large rear diffuser, roo...
# 15   other carmakers in that it is a low-cost, hig...
# 16   the BMW M3, and the Audi Q7, but with a much ...
# 17   Nike in the way it puts its marketing on disp...
# 18   Mercedes in terms of its size and its design....
# 19   the VW Golf, and it's not surprising. The Aud...
# 20   Volkswagen in that the system is designed to ...
# 21   the Subaru Impreza WRX and WRX STI, but with ...
# 22   Volkswagen in its emphasis on fuel economy, o...
# 23   other brands in that it is still selling cars...
# 24   the Porsche 911 in that it has a 2.0-liter fl...
# 25   the BMW M5. However, the Audi is powered by a...
# 26   the Volkswagen Golf, but with fewer bells and...
# 27   Volkswagen in that it is a company that has b...
# 28   BMW in that it is a luxury brand that is focu...
# 29   Chevrolet's Volt, with a range of about 100 m...
# 30   the Toyota Prius, with a base price of $40,00...
# 31   the other brands in the market, but it has th...
# 32   the other brands. The Audi brand is a very su...
# 33   Audi in that it provides a range of sound-enh...
# 34   it's predecessor, but in a more upscale packa...
# 35   the Volkswagen Golf TDI with its huge front a...
# 36   the Volkswagen Group in that it is a global c...
# 37   Audi, but not as powerful, and not as easy to...
# 38   the current Honda Civic, but the engine is a ...
# 39   the BMW i3. It has a 1.6-liter turbocharged e...
# 40   the BMW i3 in that it is a bit bigger, but no...
# 41   Honda in that there is a lot of overlap betwe...
# 42   Honda in that it's a full-size car but has a ...
# 43   the Chevrolet Corvette Z06, but with the adde...
# 44   BMW in the sense that it's a bit of a hybrid,...
# 45   BMW, but it's a little more expensive.\n\nIt'...
# 46   the Nissan Leaf, but with a much better range...
# 47   BMW. The only difference is the engine. BMW's...
# 48   other car manufacturers in that it has implem...
# 49   the German car manufacturer, with a large amo...
#
#                              Volkswagen is similar to  \
# 0    a company that doesn't own any cars.\n\nThe c...
# 1    VW in other ways, too. The company is a globa...
# 2    the company in its approach to electric cars,...
# 3    the American auto industry in their approach ...
# 4    other car companies in that it has a large nu...
# 5    Google on many levels. It is the only company...
# 6    Uber in that it has a vehicle-to-person netwo...
# 7    a car company: It has a brand, it has a produ...
# 8    other carmakers in that it has a product line...
# 9    Microsoft's Bing search engine, but with a tw...
# 10   Mercedes-Benz, but it is much more expensive ...
# 11   the Hyundai Elantra, but it has a different e...
# 12   a lot of companies in Europe that are doing t...
# 13   the Ford Motor Co. in its approach to fuel ec...
# 14   Toyota in that the company's cars are built i...
# 15   other carmakers in that it has a lot of paten...
# 16   the VW brand but with a different name. The c...
# 17   a car company in that it's not owned by a gov...
# 18   Volkswagen Group in its approach to vehicle p...
# 19   the Volkswagen Group, which produces cars for...
# 20   a traditional car manufacturer in that it mak...
# 21   General Motors in that it is a large company ...
# 22   the Volkswagen AG and Audi Group in that it h...
# 23   the auto industry in that it has a long histo...
# 24   a lot of other companies who have gone to cou...
# 25   the classic Volkswagen Beetle, but it's a bit...
# 26   multiple other companies in that it does not ...
# 27   the company that made the Volkswagen Beetle, ...
# 28   other carmakers in that it has been making ca...
# 29   other carmakers in having a large number of v...
# 30   Audi in that it is a brand that is driven by ...
# 31   Toyota in that it offers a range of vehicles ...
# 32   the U.S. auto industry, with its ownership of...
# 33   Apple in that it sells cars. But unlike Apple...
# 34   the Chinese automaker in that it's a company ...
# 35   Tesla in that it is a car company that builds...
# 36   other companies that have been accused of man...
# 37   other carmakers in not having a fully autonom...
# 38   the Volkswagen Group in that it has a monopol...
# 39   other carmakers in that it has a large amount...
# 40   the Porsche 911 Carrera, yet it is a complete...
# 41   the company that makes the Chevrolet Corvette...
# 42   the way that many companies manage their asse...
# 43   the Japanese car maker in that it doesn't mak...
# 44   the Model S in the way it uses the same engin...
# 45   Toyota, with a small production plant and a h...
# 46   Ford in that it sells cars in many different ...
# 47   General Motors in that it has been around for...
# 48   the Ford Motor Company in that it is known as...
# 49   the Volkswagen Group in the United States, wh...
#
#                                 Ferrari is similar to  \
# 0    McLaren in that it is a highly capable car, b...
# 1    the other teams in this test, but unlike the ...
# 2    the brand Ferrari. It is a brand that has bee...
# 3    Mercedes in that it is a car that is very com...
# 4    the Ferrari 458 Italia, but it's a bit more e...
# 5    the Ferrari F430, which is the same car but w...
# 6    the other Ferraris, it's the same shape as th...
# 7    the Ferrari F12 Berlinetta and is a small car...
# 8    the Ferrari 488 GTE, but it's a bit different...
# 9    the Mercedes-Benz SLS AMG, but the SLS has be...
# 10   Ferrari in that it is powered by a twin-turbo...
# 11   Ferrari in that the design of the car is simp...
# 12   Ferrari in that it has a very high floor and ...
# 13   the Ferrari of old, the Ferrari of today, and...
# 14   the Ferrari 488 GTB, Ferrari 488 GTB, Ferrari...
# 15   a Formula One car in terms of its nose shape ...
# 16   Ferrari, but it's not quite as powerful. The ...
# 17   Ferrari in that it is not quite as expensive ...
# 18   the one used in the Ferrari F12, but with a m...
# 19   Mercedes but it is much more expensive. The F...
# 20   Ferrari in that there are two versions. The f...
# 21   the Ferrari 458 Italia, but has a much higher...
# 22   the previous generation of Ferrari. It is pow...
# 23   its Ferrari counterpart, the 458, in that it'...
# 24   the McLaren MP4-12C, but with a slightly shor...
# 25   Ferrari's F1 team, but with a different car. ...
# 26   Ferrari in that they are a manufacturer, but ...
# 27   Ferrari in that it is built on a single engin...
# 28   the Ferrari 912 Spyder in that the car is a p...
# 29   Ferrari in that it's a very elegant car. It's...
# 30   the company's Senna-designed V12 engines, whi...
# 31   the Renault and BMW in that it's a car that h...
# 32   Ferrari in that it is a modern, premium car. ...
# 33   McLaren's power unit. The key difference is t...
# 34   Mercedes in terms of its design philosophy an...
# 35   the V12-powered Ferrari V12 and V12-powered F...
# 36   the Porsche 911 and Mercedes-Benz AMG GT3 in ...
# 37   Ferrari in that it has a large amount of powe...
# 38   the Ferrari 3.0-litre V6 in the Ferrari F430....
# 39   the Ferrari of today. The engine is very simi...
# 40   the Ferrari 458 Italia, the Ferrari 488 GTB a...
# 41   other brands in that it is designed for a par...
# 42   the Mercedes-Benz of the mid-1990s, with a sl...
# 43   McLaren, which is why Ferrari is now in the s...
# 44   the F1 team, it's a completely different vehi...
# 45   the Ferrari F40. It has an all-new chassis, a...
# 46   Ferrari in its ability to make a car more aff...
# 47   the Ferrari of the 1950s. The engine is a new...
# 48   Ferrari in that it is a team that has been ar...
# 49   Ferrari in the way that it has been designed ...
#
#                                   Lexus is similar to  \
# 0    the Volkswagen Beetle in its design, but with...
# 1    BMW in that it has a rear-wheel drive system,...
# 2    the Honda Civic in that they are both compact...
# 3    the BMW in terms of the styling, but it's not...
# 4    the BMW M3, but with a wider wheelbase and a ...
# 5    the Honda Accord in that it's not a hatchback...
# 6    BMW, but with a more sporty design. It's also...
# 7    the Prius, but the Prius is a hybrid of moder...
# 8    the original BMW, but with a larger engine. T...
# 9    the BMW M5, but has a higher center of gravit...
# 10   its larger sibling, the Lexus GS, in that it'...
# 11   the BMW S1000RR. However, the S1000RR has a h...
# 12   the original GT, but it's got a lot more powe...
# 13   the Lexus RX570, but the engine is a 2.0 lite...
# 14   a car with a special engine. It is powered by...
# 15   a traditional sports car, but it's not just a...
# 16   the other two in that it has a built-in GPS a...
# 17   the BMW M3, but with a larger engine and a di...
# 18   the BMW M3, which is also a compact sedan. Th...
# 19   a car in that it has a compact design and is ...
# 20   a Toyota Prius, except for the fact that it's...
# 21   the BMW model, but the car is a bit wider and...
# 22   the Nissan LEAF, with a similar range and pri...
# 23   the Toyota Camry, which makes for a much more...
# 24   the Ford Focus, but it's a little less sporty...
# 25   BMW in that it has the same engine, transmiss...
# 26   the BMW i3, but with a more powerful engine. ...
# 27   the BMW M5, but is equipped with a five-speed...
# 28   BMW's i3, but with a few minor differences. T...
# 29   Mercedes in that it has a two-door, all-wheel...
# 30   the Toyota Camry, with its V6 engine and V8 e...
# 31   the Toyota Prius, which has a manual transmis...
# 32   the BMW i3. It's a bit more sporty, and has a...
# 33   the Toyota Prius, but it is a hybrid vehicle ...
# 34   the BMW i3, which has a lower hood and a high...
# 35   the Volkswagen Golf GTI. It's also similar to...
# 36   Porsche's 911 GT3, but the car's body is much...
# 37   the Mazda3 in terms of design, but has a much...
# 38   the Toyota Camry, with its small, compact foo...
# 39   the Mazda6 in that it has a twin-turbocharged...
# 40   the BMW M3, Audi A4 and Mercedes S-Class, wit...
# 41   the BMW M3, but it has a different body style...
# 42   a motorcycle, and the way the rear wheels are...
# 43   the BMW M6 in that it has a twin-turbocharged...
# 44   the other four in that it has the same engine...
# 45   the Audi A4, but with a different engine. It ...
# 46   the BMW i3 in that it's a 2-door hatchback. L...
# 47   a BMW, but it has a more traditional look and...
# 48   Mercedes-Benz, but with a slightly different ...
# 49   the BMW M5, with a more compact, sporty look ...
#
#                                   Volvo is similar to
# 0    the Taurus in that it is a car that is design...
# 1    other brands in that it doesn't have a factor...
# 2    the Honda Accord in that it's a compact sedan...
# 3    the other cars on the market with a front-mou...
# 4    the Ford Focus Electric hybrid, which was fir...
# 5    the Ford Focus Electric, but it's a bit large...
# 6    the way the Volvo XC90 is designed. The XC90 ...
# 7    Tesla in terms of its production capacity, bu...
# 8    Honda in that it has a similar range of model...
# 9    the V60, but it has a more powerful engine an...
# 10   the XC90 in that it has a rear-wheel drive pl...
# 11   a vehicle with a rear axle. The rear axle is ...
# 12   the V90, but with an engine that's more power...
# 13   BMW's X6 and X7, but it's a bit more expensiv...
# 14   the BMW M3. It is a diesel version of the M3,...
# 15   the XC90, except that it's about as close to ...
# 16   BMW in that it is a premium car manufacturer ...
# 17   the Chevrolet Volt in terms of technology and...
# 18   the Toyota Prius, except that the Prius is a ...
# 19   the Tesla Model S, but with a slightly higher...
# 20   the BMW M3, which is a lot more powerful than...
# 21   the Volvo XC60 in that it has a full-size fou...
# 22   Ford in that it's a mid-size car that's been ...
# 23   the Volvo XC90; it's a big SUV with a lot of ...
# 24   Honda's Accord sedan, which is nearly identic...
# 25   its predecessor, the XC90, in that it offers ...
# 26   the brand of car that has sold more than 35 m...
# 27   its predecessor, the S60, in that it makes it...
# 28   the Volvo XC90, but with a few differences. T...
# 29   the U.S. version of the Chevrolet Bolt, but i...
# 30   the Honda Civic, but with an extra four doors...
# 31   Ford in that it has been around for a long ti...
# 32   Ford in that it's a small car company, and it...
# 33   the Nissan Leaf, and the two are not very dif...
# 34   Tesla in that it's a full electric car compan...
# 35   the Volvo XC90 in design, but it's a differen...
# 36   the Volvo XC90 and Volvo XC100, with a more c...
# 37   the Ford Focus, but it has a larger engine an...
# 38   Tesla's Model S, with its top speed of 155 mp...
# 39   the Toyota Prius, but with a few differences....
# 40   the XC90, but with a few differences. The XC9...
# 41   BMW in that it has a smaller engine, but it's...
# 42   the BMW 328i, and is the only one of the four...
# 43   the BMW i8 in that it is the closest thing to...
# 44   the Honda Accord, but is equipped with a more...
# 45   the Volvo XC90, but with a larger engine and ...
# 46   Tesla's Model S electric sedan, which is now ...
# 47   the BMW M3, but with more power and better ha...
# 48   the Ford Focus ST, but has a larger trunk and...
# 49   Fiat Chrysler in the way it offers a range of...
#
# [50 rows x 21 columns]

# %%
# joined=df1-df2
joined = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15], ignore_index=True)
joined
# Out:
#                                     Jeep is similar to  \
# 0     the Ford Mustang, but with a few changes. The...
# 1     its competitors in its ability to handle the ...
# 2     the Toyota Prius. The Prius is a compact, ele...
# 3     the Jeep Wrangler, which is a small SUV with ...
# 4     a truck, but it's not exactly a truck. The Je...
# ..                                                 ...
# 745   the Jeep Wrangler, which is also a Jeep brand...
# 746   the Jeep Cherokee, but it is a diesel engine ...
# 747   a Porsche 911 Turbo, but it has a different e...
# 748   the Jeep Cherokee in that it has an engine th...
# 749   a BMW. It's a compact, fun car that's capable...
#
#                                   Subaru is similar to  \
# 0     the main character in that he has very little...
# 1     the anime in that he is a boy, but he is not ...
# 2     the other characters in the series, but with ...
# 3     the other members of the group, but he does n...
# 4     an ordinary human, but he has a distinct aura...
# ..                                                 ...
# 745   the character of the same name in the TV seri...
# 746   his love interest in the original series, but...
# 747   Subaru in that he is a very happy and cheerfu...
# 748   a normal human in that he has a human body, b...
# 749   the "Super Mario Bros." series, in that he is...
#
#                                    Dodge is similar to  \
# 0     the Bumblebee, and has a similar speed, but i...
# 1     the Dodge Charger, but it has a much longer w...
# 2     the previous version of the Dodge Viper, but ...
# 3     the Dodge Viper, but has a heavier, wider bod...
# 4     the Dodge Charger, but with a lower center of...
# ..                                                 ...
# 745   the Duster.\n\nThe Duster is an improved vers...
# 746   the Dodge Viper, but with the bodywork of a V...
# 747   the "Ride-By" Dodge Viper. It sports a more a...
# 748   the previous generation of the Dodge Dart, bu...
# 749   the Dodge Viper, but features a rear spoiler ...
#
#                                    Tesla is similar to  \
# 0     the other big car makers in that it's a hybri...
# 1     Tesla Motors Inc., which has struggled to fin...
# 2     Tesla Motors, the electric car maker that has...
# 3     Tesla Motors, which is a major player in the ...
# 4     a car, but instead of a car, it's a robot. Th...
# ..                                                 ...
# 745   Tesla's Model S, but it is more affordable. T...
# 746   Tesla Motors, which is the world's largest ma...
# 747   Tesla Motors Inc., Tesla's parent company. Th...
# 748   Tesla's Model S sedan in that it is a small c...
# 749   Tesla Motors in that it has a large, global c...
#
#                                   Toyota is similar to  \
# 0     Google in that it is committed to the goal of...
# 1     the Ford Motor Company in that it's a large m...
# 2     the carmaker in its approach to fuel economy....
# 3     a Ferrari, but it has a lower price tag.\n\nT...
# 4     the VW Group in that it has a core product li...
# ..                                                 ...
# 745   the Ford Motor Company in that it has two mod...
# 746   the Chinese car maker in that it's a mass-mar...
# 747   many other car manufacturers in the U.S. with...
# 748   Ford in that it is a car company that has mad...
# 749   the other companies in the space, but it's no...
#
#                                    Honda is similar to  \
# 0     Toyota, but is not as efficient, and has a hi...
# 1     Toyota in that it is a Japanese brand, but it...
# 2     the Toyota Prius because it's a plug-in hybri...
# 3     the Honda Accord, but is equipped with a larg...
# 4     the old Honda Civic, except it has a more pow...
# ..                                                 ...
# 745   Ford in that it is a hybrid car, but it has a...
# 746   the rat's tail, so it's not surprising that t...
# 747   the Honda Civic, as it has a smaller engine a...
# 748   BMW in that it is an automaker that has a rel...
# 749   the successful Honda Civic and is also availa...
#
#                                   Nissan is similar to  \
# 0     Toyota in that it is a hybrid maker and has b...
# 1     Volkswagen, which was acquired by Volkswagen ...
# 2     Tesla, but with some unique features. It's a ...
# 3     the Prius, but it has a smaller battery and i...
# 4     Tesla in that it has set up a factory in Chin...
# ..                                                 ...
# 745   the PlayStation 3 version of the game, with t...
# 746   Tesla in that it's a big company, and it has ...
# 747   the Chevrolet Bolt EV, with a similar range o...
# 748   the Volkswagen Group in that it is a global b...
# 749   the Toyota Prius, but has a more advanced, hi...
#
#                                Chevrolet is similar to  \
# 0     Ford in that it is based on a Chevrolet Corve...
# 1     the trucking industry in that it is a company...
# 2     the Toyota Prius, but it is powered by a 1.6-...
# 3     the Chevy Volt, but with a smaller battery pa...
# 4     Ford in that it is a large automaker, but it ...
# ..                                                 ...
# 745   the Toyota Camry, but with a body made of alu...
# 746   the Ford Mustang; the differences are that th...
# 747   the Ford in that it's a little bit larger, bu...
# 748   the Nissan Leaf, but it's a much more afforda...
# 749   Chrysler in that it does not have a direct co...
#
#                                  Hyundai is similar to  \
# 0     Ford in that it offers a car that is both aff...
# 1     the Hyundai Equus, but with a higher price ta...
# 2     Volkswagen in that it is committed to making ...
# 3     Toyota in that it is an automaker that is com...
# 4     Tesla in that it uses a combination of batter...
# ..                                                 ...
# 745   Toyota in terms of the overall design, layout...
# 746   Volkswagen in that it has a strong brand iden...
# 747   Toyota in that it has a big, fat, fat SUV tha...
# 748   Tesla, with a similar product lineup. The com...
# 749   Toyota in that it is a large automaker that i...
#
#                                    Mazda is similar to  ...  \
# 0     Ford in that it is a manufacturer of cars, bu...  ...
# 1     the Mazda3, with the exception of its rear wh...  ...
# 2     Ford in that it is a car manufacturer. But it...  ...
# 3     Porsche in that it uses a new engine, a new t...  ...
# 4     Honda, but is more expensive. It is available...  ...
# ..                                                 ...  ...
# 745   GM in the sense that it's a brand. It's not a...  ...
# 746   Hyundai with its American-built vehicles. But...  ...
# 747   Mazda in that it is a traditional Japanese ca...  ...
# 748   Honda in that it has a rear-wheel drive layou...  ...
# 749   Ford in that it is a new car company, but it ...  ...
#
#                              Lamborghini is similar to  \
# 0     the Lamborghini Gallardo, but it is not as fa...
# 1     the previous generation of the Lamborghini Ga...
# 2     the Lamborghini Huracan, which is also a spor...
# 3     the Lamborghini Gallardo, but with a more pow...
# 4     Honda, which has a range of over 30,000 miles...
# ..                                                 ...
# 745   a classic sports car. It is a four-door sport...
# 746   the Lamborghini Gallardo, but without the lux...
# 747   the Italian sports car maker, but the company...
# 748   the BMW M3, but has a higher output of 140hp ...
# 749   the GMC Acadia, a four-door coupé that has so...
#
#                            Mercedes-Benz is similar to  \
# 0     the Mercedes-Benz S-Class and BMW M3, but it'...
# 1     the other brands in this category. It's a ver...
# 2     the carmaker in terms of the design and the q...
# 3     the BMW of its day, but not quite as refined....
# 4     its rival in terms of its positioning in the ...
# ..                                                 ...
# 745   Volkswagen, but they're not the same company....
# 746   Mercedes-Benz in that it is a company that ha...
# 747   Volkswagen in that it has a large number of d...
# 748   GM in that it is a car company that has a lar...
# 749   Toyota. The carmaker is also the second large...
#
#                                      BMW is similar to  \
# 0     the BMW 7 Series, which is a classic sedan th...
# 1     the company's electric car offerings, but the...
# 2     the Hyundai i30 but with a 6.2-litre V8 engin...
# 3     the BMW i3, but it comes with a few important...
# 4     the BMW 3 Series in terms of design, but has ...
# ..                                                 ...
# 745   the Volkswagen Golf GTI, but with a higher-po...
# 746   BMW's current lineup of models, but has few o...
# 747   the BMW M3, and the M3 is similar to the BMW ...
# 748   the Mercedes-Benz S-Class. The Mercedes-Benz ...
# 749   the BMW i3, with the same performance, but wi...
#
#                                     Ford is similar to  \
# 0     the Chevy Camaro, but it's a little smaller. ...
# 1     the current Toyota Camry. It has a 4-cylinder...
# 2     the '90s Honda Accord. It's got a small engin...
# 3     a person who is born with a certain amount of...
# 4     the late 19th century car, with a straight-si...
# ..                                                 ...
# 745   the Chrysler 300, which is a good car, but it...
# 746   the Ford Focus RS in terms of size, but it's ...
# 747   the Ford Mustang, with a bigger engine, large...
# 748   the "sophisticated" BMW i3, with the exceptio...
# 749   the car in the movie, but it's a different ca...
#
#                                  Porsche is similar to  \
# 0     the Porsche 911 Turbo in that it uses a 3.5-l...
# 1     Ferrari in that it is a race car manufacturer...
# 2     the previous car, but it's a little more powe...
# 3     Ford in that it is a company that has a lot o...
# 4     Ferrari in that it is a luxury brand. The new...
# ..                                                 ...
# 745   Ferrari in that it has a lot of technical kno...
# 746   the Ford Pinto, but it has a different engine...
# 747   the Volkswagen Beetle, the Porsche Panamera, ...
# 748   Apple in that it is a closed company, but it ...
# 749   Ford in that it has a reputation for quality ...
#
#                                     Audi is similar to  \
# 0     Ford, which has been producing cars since the...
# 1     other large carmakers in the world in that it...
# 2     the Audi A4, which is based on the A4, but wi...
# 3     the Audi A8, the only difference being the pr...
# 4     the Volkswagen Group, but its cars are manufa...
# ..                                                 ...
# 745   the Toyota Camry, but it's more fuel-efficien...
# 746   the Ford Focus Electric, and comes with a new...
# 747   the Audi A6 and A7. It has an engine with a d...
# 748   Ford in that it's an electric vehicle, but it...
# 749   other brands in that it has a large amount of...
#
#                               Volkswagen is similar to  \
# 0     the Japanese automaker in the way it creates ...
# 1     the other automakers in that it has a much sm...
# 2     a car company in that it is a complex machine...
# 3     the other big car makers in the United States...
# 4     the Volkswagen Group in that it is an automak...
# ..                                                 ...
# 745   Ford in that it is a vehicle maker that manuf...
# 746   Toyota and Honda in this respect. It's not ne...
# 747   Alfa Romeo in that it has a small car engine,...
# 748   the American auto industry in that it is a gl...
# 749   a traditional car manufacturer, but instead o...
#
#                                  Ferrari is similar to  \
# 0     the McLaren-Honda partnership, in that it has...
# 1     the Ferrari of the 1980s. In fact, Ferrari is...
# 2     Ferrari in that it has a low gear ratio, but ...
# 3     Ferrari in that it is a sports car company th...
# 4     the car seen at the Nurburgring in Germany, t...
# ..                                                 ...
# 745   the Honda Civic in that it has a rear-wheel d...
# 746   other Honda vehicles in that it's a four-door...
# 747   the Aston Martin Vantage in terms of its size...
# 748   the Ferrari F40, the Ferrari 458 Italia and t...
# 749   Mercedes in that it is a sportscar manufactur...
#
#                                    Lexus is similar to  \
# 0     the Porsche 911 GT3 R in that it is a sporty,...
# 1     the Mazda3 in that it is a manual car with a ...
# 2     the Camry in that it has a front-wheel drive ...
# 3     the BMW i5 and BMW i8, which are very similar...
# 4     a car's engine, but it's a lot more powerful....
# ..                                                 ...
# 745   the BMW i3 in terms of aero and handling. How...
# 746   the Porsche 911 Turbo S, but with a lot more ...
# 747   the BMW M3 in terms of features and performan...
# 748   the BMW M6, but with a more aggressive stance...
# 749   the BMW 3 Series, which is also a four-door s...
#
#                                    Volvo is similar to
# 0     Renault in that it has a number of components...
# 1     Volvo's existing range of cars, with a range ...
# 2     the Porsche 911 Turbo, but it's got a bigger ...
# 3     other automakers in that it has been producin...
# 4     the brand-new BMW i3, which has been on sale ...
# ..                                                 ...
# 745   the Toyota Prius in its fuel economy. It's ac...
# 746   Ford in that it offers a range of cars with d...
# 747   the Ford Focus ST, but has a longer wheelbase...
# 748   BMW in that it is a brand that has grown in p...
# 749   the Honda Accord, which is a pure-electric ve...
#
# [750 rows x 21 columns]

# %%
joined.to_csv("raw_text/j Dec15 750.csv")

# %%
40*15
# Out:
# 600

# %%
df1.shape
# Out:
# (21, 23)
