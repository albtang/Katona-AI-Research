# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/j Feb16 6225.csv").set_index("Unnamed: 0.1.1").drop(columns=["Unnamed: 0", "Unnamed: 0.1"])
df2 = pd.read_csv("freqs/j Mar22 6225.csv", index_col=0)
# df3 = pd.read_csv("freqs/j Mar22 reparsed Dec2 450.csv", index_col=0)
# df4 = pd.read_csv("freqs/j Mar22 reparsed Dec22 675.csv", index_col=0)
# df5 = pd.read_csv("freqs/j Mar22 reparsed Dec23 900.csv", index_col=0)
# df6 = pd.read_csv("freqs/j Mar22 reparsed Dec3 450.csv", index_col=0)
# df7 = pd.read_csv("freqs/j Mar22 reparsed Dec30 600.csv", index_col=0)
# df8 = pd.read_csv("freqs/j Mar22 reparsed Dec5 750.csv", index_col=0)
# df9 = pd.read_csv("freqs/j Mar22 reparsed Jan5 900.csv", index_col=0)

# %%
df1
# Out:
#                 Jeep is similar to  Subaru is similar to  Dodge is similar to  \
# Unnamed: 0.1.1
# Jeep                          5606                     0                   92
# Subaru                          13                  4091                    1
# Dodge                          270                     0                 5488
# Tesla                           42                     0                    4
# Toyota                         352                     9                   35
# Honda                          177                     8                   36
# Nissan                         116                     2                    6
# Chevrolet                      522                     0                   84
# Hyundai                         77                     0                   13
# Mazda                           11                     3                   14
# Renault                          2                     0                    0
# ...

# %%
# joined=df1+df2+df3+df4+df5+df6+df7+df8+df9
# joined = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15], ignore_index=True)
joined = df1-df2
joined
# Out:
#                 Jeep is similar to  Subaru is similar to  Dodge is similar to  \
# Unnamed: 0.1.1
# Jeep                            -8                     0                   -4
# Subaru                           1                     0                   -1
# Dodge                           -2                   -84                  -36
# Tesla                            1                     0                    0
# Toyota                           2                     1                    4
# Honda                            2                    -4                    5
# Nissan                          -1                     1                    0
# Chevrolet                        7                     0                    2
# Hyundai                          0                     0                    0
# Mazda                            0                     0                    1
# Renault                          1                     0                    0
# ...

# %%
joined.to_csv("freqs/j Feb16 minutes Mar22 6225.csv")

# %%
40*15
# Out:
# 600

# %%
df1.shape
# Out:
# (21, 21)
