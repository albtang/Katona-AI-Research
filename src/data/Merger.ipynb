# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Dec18 50 1.csv")
df2 = pd.read_csv("freqs/Dec18 50 2.csv")
df3 = pd.read_csv("freqs/Dec18 50 3.csv")
df4 = pd.read_csv("freqs/Dec18 50 4.csv")
df5 = pd.read_csv("freqs/Dec18 50 5.csv")
df6 = pd.read_csv("freqs/Dec18 50 6.csv")
df7 = pd.read_csv("freqs/Dec18 50 7.csv")
df8 = pd.read_csv("freqs/Dec18 50 8.csv")
df9 = pd.read_csv("freqs/Dec18 50 9.csv")
df10 = pd.read_csv("freqs/Dec18 50 10.csv")
df11 = pd.read_csv("freqs/Dec18 50 11.csv")
df12 = pd.read_csv("freqs/Dec18 50 12.csv")
df13 = pd.read_csv("freqs/Dec18 50 13.csv")
df14 = pd.read_csv("freqs/Dec18 50 14.csv")
df15 = pd.read_csv("freqs/Dec18 50 15.csv")

# %%
df1
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  46                     0
# 1          Subaru                   0                    34
# 2           Dodge                   3                     0
# 3           Tesla                   0                     0
# 4          Toyota                   3                     0
# 5           Honda                   0                     0
# 6          Nissan                   3                     0
# 7       Chevrolet                   5                     0
# 8         Hyundai                   1                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   0                     0
# 14           Ford                   7                     0
# ...

# %%
df2
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  45                     0
# 1          Subaru                   0                    33
# 2           Dodge                   2                     0
# 3           Tesla                   0                     0
# 4          Toyota                   5                     0
# 5           Honda                   2                     0
# 6          Nissan                   1                     0
# 7       Chevrolet                   5                     0
# 8         Hyundai                   0                     0
# 9           Mazda                   1                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   2                     0
# 14           Ford                   9                     0
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10+df11+df12+df13+df14+df15
joined
# Out:
#                                            Unnamed: 0  Jeep is similar to  \
# 0   JeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJe...                 668
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...                   2
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...                  35
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...                   7
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...                  43
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...                  22
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...                  12
# 7   ChevroletChevroletChevroletChevroletChevroletC...                  71
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...                   8
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...                   4
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...                   1
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...                   3
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                 668                     0
# 1          Subaru                   2                   491
# 2           Dodge                  35                     0
# 3           Tesla                   7                     0
# 4          Toyota                  43                     0
# 5           Honda                  22                     0
# 6          Nissan                  12                     0
# 7       Chevrolet                  71                     0
# 8         Hyundai                   8                     0
# 9           Mazda                   4                     0
# 10        Renault                   1                     0
# 11    Lamborghini                   3                     0
# 12  Mercedes-Benz                   6                     0
# 13            BMW                  13                     0
# 14           Ford                 110                     0
# ...

# %%
joined.to_csv("freqs/j Dec 15 750.csv")

# %%
50*15
# Out:
# 750
