# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/b Nov27 200 1.csv")
df2 = pd.read_csv("freqs/b Nov27 200 2.csv")
df3 = pd.read_csv("freqs/b Nov27 200 3.csv")
df4 = pd.read_csv("freqs/b Nov27 200 4.csv")
df5 = pd.read_csv("freqs/b Nov27 200 5.csv")
df6 = pd.read_csv("freqs/b Nov27 200 6.csv")
df7 = pd.read_csv("freqs/b Nov27 200 7.csv")
df8 = pd.read_csv("freqs/b Nov27 200 8.csv")

# %%
df1
# Out:
#        Unnamed: 0  Mercedes-Benz is similar to  Nissan is similar to
# 0            Jeep                            2                     3
# 1          Subaru                            0                     0
# 2           Dodge                            0                     1
# 3             GMC                            0                     0
# 4           Tesla                           10                    22
# 5           Buick                            0                     0
# 6          Toyota                           15                    73
# 7           Honda                            0                    27
# 8          Nissan                            1                   179
# 9       Chevrolet                            2                     4
# 10        Hyundai                            1                     5
# 11            Ram                            0                     0
# 12          Mazda                            0                     5
# ...

# %%
df2
# Out:
#        Unnamed: 0  Mercedes-Benz is similar to  Nissan is similar to
# 0            Jeep                            1                     1
# 1          Subaru                            0                     4
# 2           Dodge                            1                     0
# 3             GMC                            0                     1
# 4           Tesla                            6                    19
# 5           Buick                            0                     0
# 6          Toyota                           17                    60
# 7           Honda                            6                    22
# 8          Nissan                            4                   179
# 9       Chevrolet                            3                     5
# 10        Hyundai                            1                     2
# 11            Ram                            0                     0
# 12          Mazda                            0                     2
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8
joined
# Out:
#                                            Unnamed: 0  \
# 0                    JeepJeepJeepJeepJeepJeepJeepJeep
# 1    SubaruSubaruSubaruSubaruSubaruSubaruSubaruSubaru
# 2            DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodge
# 3                            GMCGMCGMCGMCGMCGMCGMCGMC
# 4            TeslaTeslaTeslaTeslaTeslaTeslaTeslaTesla
# 5            BuickBuickBuickBuickBuickBuickBuickBuick
# 6    ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyota
# 7            HondaHondaHondaHondaHondaHondaHondaHonda
# 8    NissanNissanNissanNissanNissanNissanNissanNissan
# 9   ChevroletChevroletChevroletChevroletChevroletC...
# 10  HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...
# 11                           RamRamRamRamRamRamRamRam
# 12           MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazda
# 13  RenaultRenaultRenaultRenaultRenaultRenaultRena...
# 14  LamborghiniLamborghiniLamborghiniLamborghiniLa...
# 15  Mercedes-BenzMercedes-BenzMercedes-BenzMercede...
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  Mercedes-Benz is similar to  Nissan is similar to
# 0            Jeep                           11                    12
# 1          Subaru                            3                    12
# 2           Dodge                            2                     2
# 3             GMC                            1                     3
# 4           Tesla                           56                   191
# 5           Buick                            0                     0
# 6          Toyota                          126                   498
# 7           Honda                           26                   182
# 8          Nissan                           26                  1402
# 9       Chevrolet                           18                    70
# 10        Hyundai                            9                    33
# 11            Ram                            0                     0
# 12          Mazda                            3                    31
# ...

# %%
joined.to_csv("freqs/j Nov 27 1600.csv")
