# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Dec3 30 1.csv")
df2 = pd.read_csv("freqs/Dec3 30 2.csv")
df3 = pd.read_csv("freqs/Dec3 30 3.csv")
df4 = pd.read_csv("freqs/Dec3 30 4.csv")
df5 = pd.read_csv("freqs/Dec3 30 5.csv")
df6 = pd.read_csv("freqs/Dec3 30 6.csv")
df7 = pd.read_csv("freqs/Dec3 30 7.csv")
df8 = pd.read_csv("freqs/Dec3 30 8.csv")
df9 = pd.read_csv("freqs/Dec3 30 9.csv")
df10 = pd.read_csv("freqs/Dec3 30 10.csv")
df11 = pd.read_csv("freqs/Dec3 30 11.csv")
df12 = pd.read_csv("freqs/Dec3 30 12.csv")
df13 = pd.read_csv("freqs/Dec3 30 13.csv")
df14 = pd.read_csv("freqs/Dec3 30 14.csv")
df15 = pd.read_csv("freqs/Dec3 30 15.csv")

# %%
df1
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  29                     0
# 1          Subaru                   0                    21
# 2           Dodge                   0                     0
# 3           Tesla                   0                     0
# 4          Toyota                   1                     0
# 5           Honda                   1                     0
# 6          Nissan                   0                     0
# 7       Chevrolet                   2                     0
# 8         Hyundai                   0                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   0                     0
# 14           Ford                   3                     0
# ...

# %%
df2
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  29                     0
# 1          Subaru                   0                    24
# 2           Dodge                   2                     0
# 3           Tesla                   0                     0
# 4          Toyota                   1                     0
# 5           Honda                   0                     1
# 6          Nissan                   0                     0
# 7       Chevrolet                   3                     0
# 8         Hyundai                   1                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   0                     0
# 14           Ford                   7                     1
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10+df11+df12+df13+df14+df15
joined
# Out:
#                                            Unnamed: 0  Jeep is similar to  \
# 0   JeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJe...                 405
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...                   1
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...                  16
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...                   3
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...                  28
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...                  19
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...                   5
# 7   ChevroletChevroletChevroletChevroletChevroletC...                  38
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...                   8
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...                   1
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...                   0
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...                   0
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                 405                     0
# 1          Subaru                   1                   298
# 2           Dodge                  16                     0
# 3           Tesla                   3                     0
# 4          Toyota                  28                     0
# 5           Honda                  19                     1
# 6          Nissan                   5                     0
# 7       Chevrolet                  38                     0
# 8         Hyundai                   8                     0
# 9           Mazda                   1                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   3                     0
# 13            BMW                   9                     0
# 14           Ford                  58                     1
# ...

# %%
joined.to_csv("freqs/j Dec 3 450.csv")
