# %%
import pandas as pd

# %%
df1 = pd.read_csv("Oct 27 small dataset 60 1.csv")
df2 = pd.read_csv("Oct 27 small dataset 60 2.csv")
df3 = pd.read_csv("Oct 27 small dataset 60 3.csv")
df4 = pd.read_csv("Oct 27 small dataset 60 4.csv")
df5 = pd.read_csv("Oct 27 small dataset 60 5.csv")
df6 = pd.read_csv("Oct 27 small dataset 60 6.csv")

# df1 = pd.read_csv("Oct 23 merged Oct 17-19.csv")
# df2 = pd.read_csv("Oct 25 merged small dataset 120.csv")

# %%
df1
# Out:
#        Unnamed: 0  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                 48                            2
# 1   Mercedes-Benz                  4                           39
# 2            Ford                  1                            1
# 3         Hyundai                  0                            0
# 4             Kia                  0                            1
# 5             Ram                  0                            0
# 6          Subaru                  0                            0
# 7            Jeep                  0                            0
# 8          Toyota                  1                            1
# 9       Chevrolet                  0                            0
# 10          Honda                  0                            1
# 11           Audi                  2                            1
# 12          Lexus                  0                            1
# ...

# %%
df2
# Out:
#        Unnamed: 0  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                 46                            2
# 1   Mercedes-Benz                  4                           39
# 2            Ford                  1                            0
# 3         Hyundai                  0                            0
# 4             Kia                  0                            0
# 5             Ram                  0                            0
# 6          Subaru                  1                            0
# 7            Jeep                  0                            0
# 8          Toyota                  1                            0
# 9       Chevrolet                  0                            0
# 10          Honda                  0                            0
# 11           Audi                  2                            1
# 12          Lexus                  0                            1
# ...

# %%
joined = df1+df2+df3+df4+df5+df6
# joined = joined.drop(columns=['Unnamed: 0'])
joined
# Out:
#                                            Unnamed: 0  The car brand BMW  \
# 0                                  BMWBMWBMWBMWBMWBMW                298
# 1   Mercedes-BenzMercedes-BenzMercedes-BenzMercede...                 24
# 2                            FordFordFordFordFordFord                  5
# 3          HyundaiHyundaiHyundaiHyundaiHyundaiHyundai                  1
# 4                                  KiaKiaKiaKiaKiaKia                  0
# 5                                  RamRamRamRamRamRam                  0
# 6                SubaruSubaruSubaruSubaruSubaruSubaru                  1
# 7                            JeepJeepJeepJeepJeepJeep                  0
# 8                ToyotaToyotaToyotaToyotaToyotaToyota                  6
# 9   ChevroletChevroletChevroletChevroletChevroletC...                  1
# 10                     HondaHondaHondaHondaHondaHonda                  0
# 11                           AudiAudiAudiAudiAudiAudi                 11
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand BMW  The car brand Mercedes-Benz  \
# 0             BMW                298                           15
# 1   Mercedes-Benz                 24                          244
# 2            Ford                  5                            7
# 3         Hyundai                  1                            0
# 4             Kia                  0                            1
# 5             Ram                  0                            0
# 6          Subaru                  1                            0
# 7            Jeep                  0                            0
# 8          Toyota                  6                            5
# 9       Chevrolet                  1                            0
# 10          Honda                  0                            1
# 11           Audi                 11                            8
# 12          Lexus                  1                            3
# ...

# %%
joined.to_csv("Oct 28 merged small dataset 360.csv")
