# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Dec2 30 1.csv")
df2 = pd.read_csv("freqs/Dec2 30 2.csv")
df3 = pd.read_csv("freqs/Dec2 30 3.csv")
df4 = pd.read_csv("freqs/Dec2 30 4.csv")
df5 = pd.read_csv("freqs/Dec2 30 5.csv")
df6 = pd.read_csv("freqs/Dec2 30 6.csv")
df7 = pd.read_csv("freqs/Dec2 30 7.csv")
df8 = pd.read_csv("freqs/Dec2 30 8.csv")
df9 = pd.read_csv("freqs/Dec2 30 9.csv")
df10 = pd.read_csv("freqs/Dec2 30 10.csv")
df11 = pd.read_csv("freqs/Dec2 30 11.csv")
df12 = pd.read_csv("freqs/Dec2 30 12.csv")
df13 = pd.read_csv("freqs/Dec2 30 13.csv")
df14 = pd.read_csv("freqs/Dec2 30 14.csv")
df15 = pd.read_csv("freqs/Dec2 30 15.csv")

# %%
df1
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  30                     0
# 1          Subaru                   1                    20
# 2           Dodge                   0                     0
# 3           Tesla                   0                     0
# 4          Toyota                   2                     0
# 5           Honda                   2                     0
# 6          Nissan                   0                     0
# 7       Chevrolet                   3                     0
# 8         Hyundai                   0                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   1                     0
# 13            BMW                   0                     0
# 14           Ford                   3                     0
# ...

# %%
df2
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  28                     0
# 1          Subaru                   0                    21
# 2           Dodge                   1                     0
# 3           Tesla                   1                     0
# 4          Toyota                   3                     0
# 5           Honda                   0                     0
# 6          Nissan                   1                     0
# 7       Chevrolet                   1                     0
# 8         Hyundai                   0                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   0                     0
# 14           Ford                   4                     0
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10+df11+df12+df13+df14+df15
joined
# Out:
#                                            Unnamed: 0  Jeep is similar to  \
# 0   JeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJe...                 415
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...                   2
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...                  18
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...                   3
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...                  26
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...                  12
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...                  11
# 7   ChevroletChevroletChevroletChevroletChevroletC...                  34
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...                   7
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...                   0
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...                   0
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...                   0
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                 415                     0
# 1          Subaru                   2                   307
# 2           Dodge                  18                     0
# 3           Tesla                   3                     0
# 4          Toyota                  26                     1
# 5           Honda                  12                     1
# 6          Nissan                  11                     0
# 7       Chevrolet                  34                     0
# 8         Hyundai                   7                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   1                     0
# 13            BMW                   4                     0
# 14           Ford                  59                     0
# ...

# %%
joined.to_csv("freqs/j Dec 2 450.csv")
