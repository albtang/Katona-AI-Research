# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/b Nov26 400 1.csv")
df2 = pd.read_csv("freqs/b Nov26 400 2.csv")
df3 = pd.read_csv("freqs/b Nov26 400 3.csv")
df4 = pd.read_csv("freqs/b Nov26 400 4.csv")
df5 = pd.read_csv("freqs/b Nov26 400 5.csv")

# %%
df1
# Out:
#        Unnamed: 0  The car brand is similar to
# 0            Audi                           43
# 1             BMW                           99
# 2           Buick                            0
# 3       Chevrolet                           18
# 4           Dodge                            1
# 5         Ferrari                           46
# 6            Ford                           63
# 7             GMC                            2
# 8           Honda                           34
# 9         Hyundai                           10
# 10       Infiniti                            0
# 11           Jeep                           15
# 12    Lamborghini                            6
# 13          Lexus                            7
# 14             MG                            0
# 15          Mazda                            3
# 16  Mercedes-Benz                          125
# 17         Nissan                           12
# 18        Porsche                           44
# ...

# %%
df2
# Out:
#        Unnamed: 0  The car brand is similar to
# 0            Audi                           67
# 1             BMW                          109
# 2           Buick                            2
# 3       Chevrolet                           15
# 4           Dodge                            0
# 5         Ferrari                           49
# 6            Ford                           69
# 7             GMC                            2
# 8           Honda                           16
# 9         Hyundai                            3
# 10       Infiniti                            0
# 11           Jeep                           16
# 12    Lamborghini                            6
# 13          Lexus                            5
# 14             MG                            0
# 15          Mazda                            8
# 16  Mercedes-Benz                          122
# 17         Nissan                           15
# 18        Porsche                           48
# ...

# %%
joined = df1+df2+df3+df4+df5
# joined = joined.drop(columns=['Unnamed: 0'])
joined
# Out:
#                                            Unnamed: 0  \
# 0                                AudiAudiAudiAudiAudi
# 1                                     BMWBMWBMWBMWBMW
# 2                           BuickBuickBuickBuickBuick
# 3       ChevroletChevroletChevroletChevroletChevrolet
# 4                           DodgeDodgeDodgeDodgeDodge
# 5                 FerrariFerrariFerrariFerrariFerrari
# 6                                FordFordFordFordFord
# 7                                     GMCGMCGMCGMCGMC
# 8                           HondaHondaHondaHondaHonda
# 9                 HyundaiHyundaiHyundaiHyundaiHyundai
# 10           InfinitiInfinitiInfinitiInfinitiInfiniti
# 11                               JeepJeepJeepJeepJeep
# 12  LamborghiniLamborghiniLamborghiniLamborghiniLa...
# 13                          LexusLexusLexusLexusLexus
# 14                                         MGMGMGMGMG
# 15                          MazdaMazdaMazdaMazdaMazda
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand is similar to
# 0            Audi                          297
# 1             BMW                          546
# 2           Buick                            2
# 3       Chevrolet                           69
# 4           Dodge                            7
# 5         Ferrari                          221
# 6            Ford                          334
# 7             GMC                            4
# 8           Honda                          127
# 9         Hyundai                           33
# 10       Infiniti                            1
# 11           Jeep                           63
# 12    Lamborghini                           33
# 13          Lexus                           26
# 14             MG                            2
# 15          Mazda                           36
# 16  Mercedes-Benz                          636
# 17         Nissan                           81
# 18        Porsche                          228
# ...

# %%
joined.to_csv("freqs/j Nov 26 2000.csv")
