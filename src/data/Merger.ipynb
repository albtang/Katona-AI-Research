# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Dec1 30 1.csv")
df2 = pd.read_csv("freqs/Dec1 30 2.csv")
df3 = pd.read_csv("freqs/Dec1 30 3.csv")
df4 = pd.read_csv("freqs/Dec1 30 4.csv")
df5 = pd.read_csv("freqs/Dec1 30 5.csv")
df6 = pd.read_csv("freqs/Dec1 30 6.csv")
df7 = pd.read_csv("freqs/Dec1 30 7.csv")
df8 = pd.read_csv("freqs/Dec1 30 8.csv")
df9 = pd.read_csv("freqs/Dec1 30 9.csv")
df10 = pd.read_csv("freqs/Dec1 30 10.csv")
df11 = pd.read_csv("freqs/Dec1 30 11.csv")
df12 = pd.read_csv("freqs/Dec1 30 12.csv")
df13 = pd.read_csv("freqs/Dec1 30 13.csv")
df14 = pd.read_csv("freqs/Dec1 30 14.csv")
df15 = pd.read_csv("freqs/Dec1 30 15.csv")

# %%
df1
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                                22
# 1          Subaru                                 0
# 2           Dodge                                 1
# 3           Tesla                                 2
# 4          Toyota                                 4
# 5           Honda                                 1
# 6          Nissan                                 1
# 7       Chevrolet                                 1
# 8         Hyundai                                 0
# 9           Mazda                                 0
# 10        Renault                                 0
# 11    Lamborghini                                 0
# 12  Mercedes-Benz                                 2
# 13            BMW                                 3
# 14           Ford                                16
# 15        Porsche                                 0
# 16           Audi                                 1
# ...

# %%
df2
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                                27
# 1          Subaru                                 1
# 2           Dodge                                 1
# 3           Tesla                                 0
# 4          Toyota                                 2
# 5           Honda                                 0
# 6          Nissan                                 0
# 7       Chevrolet                                 2
# 8         Hyundai                                 0
# 9           Mazda                                 0
# 10        Renault                                 0
# 11    Lamborghini                                 0
# 12  Mercedes-Benz                                 2
# 13            BMW                                 1
# 14           Ford                                22
# 15        Porsche                                 0
# 16           Audi                                 0
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10+df11+df12+df13+df14+df15
joined
# Out:
#                                            Unnamed: 0  \
# 0   JeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJe...
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...
# 7   ChevroletChevroletChevroletChevroletChevroletC...
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...
# 12  Mercedes-BenzMercedes-BenzMercedes-BenzMercede...
# 13      BMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMW
# 14  FordFordFordFordFordFordFordFordFordFordFordFo...
# 15  PorschePorschePorschePorschePorschePorschePors...
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                               364
# 1          Subaru                                 6
# 2           Dodge                                11
# 3           Tesla                                20
# 4          Toyota                                63
# 5           Honda                                15
# 6          Nissan                                13
# 7       Chevrolet                                24
# 8         Hyundai                                 5
# 9           Mazda                                 4
# 10        Renault                                 1
# 11    Lamborghini                                 1
# 12  Mercedes-Benz                                36
# 13            BMW                                28
# 14           Ford                               277
# 15        Porsche                                 6
# 16           Audi                                 8
# ...

# %%
joined.to_csv("freqs/j Dec 1 450.csv")
