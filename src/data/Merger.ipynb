# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Dec22 45 1.csv")
df2 = pd.read_csv("freqs/Dec22 45 2.csv")
df3 = pd.read_csv("freqs/Dec22 45 3.csv")
df4 = pd.read_csv("freqs/Dec22 45 4.csv")
df5 = pd.read_csv("freqs/Dec22 45 5.csv")
df6 = pd.read_csv("freqs/Dec22 45 6.csv")
df7 = pd.read_csv("freqs/Dec22 45 7.csv")
df8 = pd.read_csv("freqs/Dec22 45 8.csv")
df9 = pd.read_csv("freqs/Dec22 45 9.csv")
df10 = pd.read_csv("freqs/Dec22 45 10.csv")
df11 = pd.read_csv("freqs/Dec22 45 11.csv")
df12 = pd.read_csv("freqs/Dec22 45 12.csv")
df13 = pd.read_csv("freqs/Dec22 45 13.csv")
df14 = pd.read_csv("freqs/Dec22 45 14.csv")
df15 = pd.read_csv("freqs/Dec22 45 15.csv")

# %%
df1
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  43                     0
# 1          Subaru                   0                    30
# 2           Dodge                   0                     0
# 3           Tesla                   0                     0
# 4          Toyota                   2                     0
# 5           Honda                   2                     0
# 6          Nissan                   1                     0
# 7       Chevrolet                   3                     0
# 8         Hyundai                   2                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   0                     0
# 14           Ford                   4                     0
# ...

# %%
df2
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  42                     0
# 1          Subaru                   0                    25
# 2           Dodge                   3                     0
# 3           Tesla                   1                     0
# 4          Toyota                   0                     0
# 5           Honda                   0                     0
# 6          Nissan                   0                     0
# 7       Chevrolet                   4                     0
# 8         Hyundai                   1                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   0                     0
# 14           Ford                   3                     0
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10+df11+df12+df13+df14+df15
joined
# Out:
#                                            Unnamed: 0  Jeep is similar to  \
# 0   JeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJe...                 606
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...                   0
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...                  33
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...                   7
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...                  31
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...                  16
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...                  13
# 7   ChevroletChevroletChevroletChevroletChevroletC...                  56
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...                  11
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...                   0
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...                   0
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...                   0
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                 606                     0
# 1          Subaru                   0                   417
# 2           Dodge                  33                     0
# 3           Tesla                   7                     0
# 4          Toyota                  31                     0
# 5           Honda                  16                     1
# 6          Nissan                  13                     0
# 7       Chevrolet                  56                     0
# 8         Hyundai                  11                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   4                     0
# 13            BMW                   8                     0
# 14           Ford                  90                     1
# ...

# %%
joined.to_csv("freqs/j Dec 22 675.csv")

# %%
45*15
# Out:
# 675
