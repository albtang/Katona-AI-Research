# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Nov28 40 1.csv")
df2 = pd.read_csv("freqs/Nov28 40 2.csv")
df3 = pd.read_csv("freqs/Nov28 40 3.csv")
df4 = pd.read_csv("freqs/Nov28 40 4.csv")
df5 = pd.read_csv("freqs/Nov28 40 5.csv")
df6 = pd.read_csv("freqs/Nov28 40 6.csv")
df7 = pd.read_csv("freqs/Nov28 40 7.csv")
df8 = pd.read_csv("freqs/Nov28 40 8.csv")
df9 = pd.read_csv("freqs/Nov28 40 9.csv")
df10 = pd.read_csv("freqs/Nov28 40 10.csv")

# %%
df1
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                                36
# 1          Subaru                                 0
# 2           Dodge                                 1
# 3           Tesla                                 3
# 4          Toyota                                 2
# 5           Honda                                 0
# 6          Nissan                                 0
# 7       Chevrolet                                 1
# 8         Hyundai                                 0
# 9           Mazda                                 0
# 10        Renault                                 0
# 11    Lamborghini                                 0
# 12  Mercedes-Benz                                 1
# 13            BMW                                 4
# 14           Ford                                23
# 15        Porsche                                 1
# 16           Audi                                 3
# ...

# %%
df2
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                                32
# 1          Subaru                                 1
# 2           Dodge                                 1
# 3           Tesla                                 1
# 4          Toyota                                 9
# 5           Honda                                 2
# 6          Nissan                                 2
# 7       Chevrolet                                 3
# 8         Hyundai                                 0
# 9           Mazda                                 1
# 10        Renault                                 0
# 11    Lamborghini                                 0
# 12  Mercedes-Benz                                 1
# 13            BMW                                 1
# 14           Ford                                22
# 15        Porsche                                 0
# 16           Audi                                 2
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10
joined
# Out:
#                                            Unnamed: 0  \
# 0            JeepJeepJeepJeepJeepJeepJeepJeepJeepJeep
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...
# 7   ChevroletChevroletChevroletChevroletChevroletC...
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...
# 12  Mercedes-BenzMercedes-BenzMercedes-BenzMercede...
# 13                     BMWBMWBMWBMWBMWBMWBMWBMWBMWBMW
# 14           FordFordFordFordFordFordFordFordFordFord
# 15  PorschePorschePorschePorschePorschePorschePors...
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                               320
# 1          Subaru                                11
# 2           Dodge                                 9
# 3           Tesla                                26
# 4          Toyota                                58
# 5           Honda                                13
# 6          Nissan                                11
# 7       Chevrolet                                27
# 8         Hyundai                                 7
# 9           Mazda                                 3
# 10        Renault                                 2
# 11    Lamborghini                                 0
# 12  Mercedes-Benz                                28
# 13            BMW                                26
# 14           Ford                               241
# 15        Porsche                                 7
# 16           Audi                                18
# ...

# %%
joined.to_csv("freqs/j Nov 28 400.csv")
