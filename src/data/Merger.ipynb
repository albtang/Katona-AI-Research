# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Nov30 30 1.csv")
df2 = pd.read_csv("freqs/Nov30 30 2.csv")
df3 = pd.read_csv("freqs/Nov30 30 3.csv")
df4 = pd.read_csv("freqs/Nov30 30 4.csv")
df5 = pd.read_csv("freqs/Nov30 30 5.csv")
df6 = pd.read_csv("freqs/Nov30 30 6.csv")
df7 = pd.read_csv("freqs/Nov30 30 7.csv")
df8 = pd.read_csv("freqs/Nov30 30 8.csv")
df9 = pd.read_csv("freqs/Nov30 30 9.csv")
df10 = pd.read_csv("freqs/Nov30 30 10.csv")
df11 = pd.read_csv("freqs/Nov30 30 11.csv")
# df12 = pd.read_csv("freqs/Nov30 30 12.csv")
df13 = pd.read_csv("freqs/Nov30 30 13.csv")
df14 = pd.read_csv("freqs/Nov30 30 14.csv")

# %%
df1
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                                24
# 1          Subaru                                 0
# 2           Dodge                                 3
# 3           Tesla                                 2
# 4          Toyota                                 6
# 5           Honda                                 1
# 6          Nissan                                 2
# 7       Chevrolet                                 2
# 8         Hyundai                                 1
# 9           Mazda                                 0
# 10        Renault                                 0
# 11    Lamborghini                                 0
# 12  Mercedes-Benz                                 2
# 13            BMW                                 5
# 14           Ford                                16
# 15        Porsche                                 0
# 16           Audi                                 3
# ...

# %%
df2
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                                21
# 1          Subaru                                 0
# 2           Dodge                                 0
# 3           Tesla                                 1
# 4          Toyota                                 3
# 5           Honda                                 0
# 6          Nissan                                 0
# 7       Chevrolet                                 1
# 8         Hyundai                                 0
# 9           Mazda                                 0
# 10        Renault                                 0
# 11    Lamborghini                                 0
# 12  Mercedes-Benz                                 2
# 13            BMW                                 0
# 14           Ford                                20
# 15        Porsche                                 0
# 16           Audi                                 0
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10+df11+df13+df14
joined
# Out:
#                                            Unnamed: 0  \
# 0   JeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJe...
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...
# 7   ChevroletChevroletChevroletChevroletChevroletC...
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...
# 12  Mercedes-BenzMercedes-BenzMercedes-BenzMercede...
# 13            BMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMW
# 14  FordFordFordFordFordFordFordFordFordFordFordFo...
# 15  PorschePorschePorschePorschePorschePorschePors...
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand Jeep is similar to  \
# 0            Jeep                               235
# 1          Subaru                                 4
# 2           Dodge                                 8
# 3           Tesla                                13
# 4          Toyota                                52
# 5           Honda                                12
# 6          Nissan                                11
# 7       Chevrolet                                16
# 8         Hyundai                                 3
# 9           Mazda                                 2
# 10        Renault                                 0
# 11    Lamborghini                                 1
# 12  Mercedes-Benz                                17
# 13            BMW                                21
# 14           Ford                               204
# 15        Porsche                                 4
# 16           Audi                                10
# ...

# %%
joined.to_csv("freqs/j Nov 30 390.csv")
