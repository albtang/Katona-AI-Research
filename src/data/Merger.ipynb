# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/Dec5 50 1.csv")
df2 = pd.read_csv("freqs/Dec5 50 2.csv")
df3 = pd.read_csv("freqs/Dec5 50 3.csv")
df4 = pd.read_csv("freqs/Dec5 50 4.csv")
df5 = pd.read_csv("freqs/Dec5 50 5.csv")
df6 = pd.read_csv("freqs/Dec5 50 6.csv")
df7 = pd.read_csv("freqs/Dec5 50 7.csv")
df8 = pd.read_csv("freqs/Dec5 50 8.csv")
df9 = pd.read_csv("freqs/Dec5 50 9.csv")
df10 = pd.read_csv("freqs/Dec5 50 10.csv")
df11 = pd.read_csv("freqs/Dec5 50 11.csv")
df12 = pd.read_csv("freqs/Dec5 50 12.csv")
df13 = pd.read_csv("freqs/Dec5 50 13.csv")
df14 = pd.read_csv("freqs/Dec5 50 14.csv")
df15 = pd.read_csv("freqs/Dec5 50 15.csv")

# %%
df1
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  49                     0
# 1          Subaru                   0                    35
# 2           Dodge                   1                     0
# 3           Tesla                   0                     0
# 4          Toyota                   7                     0
# 5           Honda                   1                     0
# 6          Nissan                   2                     0
# 7       Chevrolet                   7                     0
# 8         Hyundai                   2                     0
# 9           Mazda                   1                     1
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   0                     0
# 13            BMW                   0                     0
# 14           Ford                  11                     0
# ...

# %%
df2
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                  41                     0
# 1          Subaru                   0                    36
# 2           Dodge                   3                     0
# 3           Tesla                   0                     0
# 4          Toyota                   4                     0
# 5           Honda                   5                     1
# 6          Nissan                   3                     0
# 7       Chevrolet                   2                     0
# 8         Hyundai                   0                     0
# 9           Mazda                   0                     0
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   1                     0
# 13            BMW                   2                     0
# 14           Ford                   8                     0
# ...

# %%
joined = df1+df2+df3+df4+df5+df6+df7+df8+df9+df10+df11+df12+df13+df14+df15
joined
# Out:
#                                            Unnamed: 0  Jeep is similar to  \
# 0   JeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJeepJe...                 675
# 1   SubaruSubaruSubaruSubaruSubaruSubaruSubaruSuba...                   0
# 2   DodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeDodgeD...                  28
# 3   TeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaTeslaT...                   2
# 4   ToyotaToyotaToyotaToyotaToyotaToyotaToyotaToyo...                  42
# 5   HondaHondaHondaHondaHondaHondaHondaHondaHondaH...                  21
# 6   NissanNissanNissanNissanNissanNissanNissanNiss...                  16
# 7   ChevroletChevroletChevroletChevroletChevroletC...                  58
# 8   HyundaiHyundaiHyundaiHyundaiHyundaiHyundaiHyun...                   8
# 9   MazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaMazdaM...                   1
# 10  RenaultRenaultRenaultRenaultRenaultRenaultRena...                   0
# 11  LamborghiniLamborghiniLamborghiniLamborghiniLa...                   0
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  Jeep is similar to  Subaru is similar to  \
# 0            Jeep                 675                     0
# 1          Subaru                   0                   475
# 2           Dodge                  28                     0
# 3           Tesla                   2                     0
# 4          Toyota                  42                     2
# 5           Honda                  21                     1
# 6          Nissan                  16                     1
# 7       Chevrolet                  58                     0
# 8         Hyundai                   8                     0
# 9           Mazda                   1                     2
# 10        Renault                   0                     0
# 11    Lamborghini                   0                     0
# 12  Mercedes-Benz                   6                     0
# 13            BMW                   9                     0
# 14           Ford                 108                     1
# ...

# %%
joined.to_csv("freqs/j Dec 5 750.csv")

# %%
50*15
# Out:
# 750
