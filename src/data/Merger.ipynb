# %%
import pandas as pd

# %%
df1 = pd.read_csv("freqs/b Nov21 500 1.csv")
df2 = pd.read_csv("freqs/b Nov21 500 2.csv")
df3 = pd.read_csv("freqs/b Nov21 500 3.csv")
df4 = pd.read_csv("freqs/b Nov21 500 4.csv")
df5 = pd.read_csv("freqs/b Nov21 500 5.csv")
# df6 = pd.read_csv("Oct 27 small dataset 60 6.csv")

# df1 = pd.read_csv("Oct 23 merged Oct 17-19.csv")
# df2 = pd.read_csv("Oct 25 merged small dataset 120.csv")

# %%
df1
# Out:
#        Unnamed: 0  The car brand is similar to
# 0            Audi                           70
# 1             BMW                          123
# 2           Buick                            0
# 3       Chevrolet                           13
# 4           Dodge                            2
# 5         Ferrari                           42
# 6            Ford                           87
# 7             GMC                            0
# 8           Honda                           37
# 9         Hyundai                           14
# 10       Infiniti                            2
# 11           Jeep                           28
# 12    Lamborghini                            9
# 13          Lexus                            4
# 14             MG                            0
# 15          Mazda                            6
# 16  Mercedes-Benz                          389
# 17         Nissan                           24
# 18        Porsche                           70
# ...

# %%
df2
# Out:
#        Unnamed: 0  The car brand is similar to
# 0            Audi                           72
# 1             BMW                          126
# 2           Buick                            0
# 3       Chevrolet                           18
# 4           Dodge                            1
# 5         Ferrari                           55
# 6            Ford                          101
# 7             GMC                            2
# 8           Honda                           39
# 9         Hyundai                           18
# 10       Infiniti                            0
# 11           Jeep                           21
# 12    Lamborghini                           12
# 13          Lexus                            4
# 14             MG                            0
# 15          Mazda                            4
# 16  Mercedes-Benz                          375
# 17         Nissan                           21
# 18        Porsche                           57
# ...

# %%
joined = df1+df2+df3+df4+df5
# joined = joined.drop(columns=['Unnamed: 0'])
joined
# Out:
#                                            Unnamed: 0  \
# 0                                AudiAudiAudiAudiAudi
# 1                                     BMWBMWBMWBMWBMW
# 2                           BuickBuickBuickBuickBuick
# 3       ChevroletChevroletChevroletChevroletChevrolet
# 4                           DodgeDodgeDodgeDodgeDodge
# 5                 FerrariFerrariFerrariFerrariFerrari
# 6                                FordFordFordFordFord
# 7                                     GMCGMCGMCGMCGMC
# 8                           HondaHondaHondaHondaHonda
# 9                 HyundaiHyundaiHyundaiHyundaiHyundai
# 10           InfinitiInfinitiInfinitiInfinitiInfiniti
# 11                               JeepJeepJeepJeepJeep
# 12  LamborghiniLamborghiniLamborghiniLamborghiniLa...
# 13                          LexusLexusLexusLexusLexus
# 14                                         MGMGMGMGMG
# 15                          MazdaMazdaMazdaMazdaMazda
# ...

# %%
joined['Unnamed: 0'] = df1['Unnamed: 0']

# %%
joined
# Out:
#        Unnamed: 0  The car brand is similar to
# 0            Audi                          390
# 1             BMW                          648
# 2           Buick                            1
# 3       Chevrolet                           86
# 4           Dodge                           10
# 5         Ferrari                          256
# 6            Ford                          444
# 7             GMC                            6
# 8           Honda                          183
# 9         Hyundai                           55
# 10       Infiniti                            3
# 11           Jeep                          107
# 12    Lamborghini                           49
# 13          Lexus                           22
# 14             MG                            0
# 15          Mazda                           46
# 16  Mercedes-Benz                         1978
# 17         Nissan                          110
# 18        Porsche                          309
# ...

# %%
joined.to_csv("freqs/j Nov 21 2500.csv")
