# %%
import pandas as pd
import numpy as np

# %%
raw1 = pd.read_csv("raw_text/Apr1 50 1.csv", index_col=0)
raw2 = pd.read_csv("raw_text/Apr1 50 2.csv", index_col=0)
raw3 = pd.read_csv("raw_text/Apr1 50 3.csv", index_col=0)
raw4 = pd.read_csv("raw_text/Apr1 50 4.csv", index_col=0)
raw5 = pd.read_csv("raw_text/Apr1 50 5.csv", index_col=0)
raw6 = pd.read_csv("raw_text/Apr1 50 6.csv", index_col=0)
raw7 = pd.read_csv("raw_text/Apr1 50 7.csv", index_col=0)
raw8 = pd.read_csv("raw_text/Apr1 50 8.csv", index_col=0)
raw9 = pd.read_csv("raw_text/Apr1 50 9.csv", index_col=0)
raw10 = pd.read_csv("raw_text/Apr1 50 10.csv", index_col=0)
raw11 = pd.read_csv("raw_text/Apr1 50 11.csv", index_col=0)
raw12 = pd.read_csv("raw_text/Apr1 50 12.csv", index_col=0)
raw13 = pd.read_csv("raw_text/Apr1 50 13.csv", index_col=0)
raw14 = pd.read_csv("raw_text/Apr1 50 14.csv", index_col=0)
raw15 = pd.read_csv("raw_text/Apr1 50 15.csv", index_col=0)

raw_1 = pd.read_csv("raw_text/Apr10 50 1.csv", index_col=0)
raw_2 = pd.read_csv("raw_text/Apr10 50 2.csv", index_col=0)
raw_3 = pd.read_csv("raw_text/Apr10 50 3.csv", index_col=0)
raw_4 = pd.read_csv("raw_text/Apr10 50 4.csv", index_col=0)
raw_5 = pd.read_csv("raw_text/Apr10 50 5.csv", index_col=0)
raw_6 = pd.read_csv("raw_text/Apr10 50 6.csv", index_col=0)
raw_7 = pd.read_csv("raw_text/Apr10 50 7.csv", index_col=0)
raw_8 = pd.read_csv("raw_text/Apr10 50 8.csv", index_col=0)
raw_9 = pd.read_csv("raw_text/Apr10 50 9.csv", index_col=0)
raw_10 = pd.read_csv("raw_text/Apr10 50 10.csv", index_col=0)
raw_11 = pd.read_csv("raw_text/Apr10 50 11.csv", index_col=0)
raw_12 = pd.read_csv("raw_text/Apr10 50 12.csv", index_col=0)
raw_13 = pd.read_csv("raw_text/Apr10 50 13.csv", index_col=0)
raw_14 = pd.read_csv("raw_text/Apr10 50 14.csv", index_col=0)
raw_15 = pd.read_csv("raw_text/Apr10 50 15.csv", index_col=0)

raw__1 = pd.read_csv("raw_text/Apr13 50 1.csv", index_col=0)
raw__2 = pd.read_csv("raw_text/Apr13 50 2.csv", index_col=0)
raw__3 = pd.read_csv("raw_text/Apr13 50 3.csv", index_col=0)
raw__4 = pd.read_csv("raw_text/Apr13 50 4.csv", index_col=0)
raw__5 = pd.read_csv("raw_text/Apr13 50 5.csv", index_col=0)
raw__6 = pd.read_csv("raw_text/Apr13 50 6.csv", index_col=0)
raw__7 = pd.read_csv("raw_text/Apr13 50 7.csv", index_col=0)
raw__8 = pd.read_csv("raw_text/Apr13 50 8.csv", index_col=0)
raw__9 = pd.read_csv("raw_text/Apr13 50 9.csv", index_col=0)
raw__10 = pd.read_csv("raw_text/Apr13 50 10.csv", index_col=0)
raw__11 = pd.read_csv("raw_text/Apr13 50 11.csv", index_col=0)
raw__12 = pd.read_csv("raw_text/Apr13 50 12.csv", index_col=0)
raw__13 = pd.read_csv("raw_text/Apr13 50 13.csv", index_col=0)
raw__14 = pd.read_csv("raw_text/Apr13 50 14.csv", index_col=0)
raw__15 = pd.read_csv("raw_text/Apr13 50 15.csv", index_col=0)

raw___1 = pd.read_csv("raw_text/Apr15 50 1.csv", index_col=0)
raw___2 = pd.read_csv("raw_text/Apr15 50 2.csv", index_col=0)
raw___3 = pd.read_csv("raw_text/Apr15 50 3.csv", index_col=0)
raw___4 = pd.read_csv("raw_text/Apr15 50 4.csv", index_col=0)
raw___5 = pd.read_csv("raw_text/Apr15 50 5.csv", index_col=0)
raw___6 = pd.read_csv("raw_text/Apr15 50 6.csv", index_col=0)
raw___7 = pd.read_csv("raw_text/Apr15 50 7.csv", index_col=0)
raw___8 = pd.read_csv("raw_text/Apr15 50 8.csv", index_col=0)
raw___9 = pd.read_csv("raw_text/Apr15 50 9.csv", index_col=0)
raw___10 = pd.read_csv("raw_text/Apr15 50 10.csv", index_col=0)
raw___11 = pd.read_csv("raw_text/Apr15 50 11.csv", index_col=0)
raw___12 = pd.read_csv("raw_text/Apr15 50 12.csv", index_col=0)
raw___13 = pd.read_csv("raw_text/Apr15 50 13.csv", index_col=0)
raw___14 = pd.read_csv("raw_text/Apr15 50 14.csv", index_col=0)
raw___15 = pd.read_csv("raw_text/Apr15 50 15.csv", index_col=0)

raw____1 = pd.read_csv("raw_text/Apr18 50 1.csv", index_col=0)
raw____2 = pd.read_csv("raw_text/Apr18 50 2.csv", index_col=0)
raw____3 = pd.read_csv("raw_text/Apr18 50 3.csv", index_col=0)
raw____4 = pd.read_csv("raw_text/Apr18 50 4.csv", index_col=0)
raw____5 = pd.read_csv("raw_text/Apr18 50 5.csv", index_col=0)
raw____6 = pd.read_csv("raw_text/Apr18 50 6.csv", index_col=0)
raw____7 = pd.read_csv("raw_text/Apr18 50 7.csv", index_col=0)
raw____8 = pd.read_csv("raw_text/Apr18 50 8.csv", index_col=0)
raw____9 = pd.read_csv("raw_text/Apr18 50 9.csv", index_col=0)
raw____10 = pd.read_csv("raw_text/Apr18 50 10.csv", index_col=0)
raw____11 = pd.read_csv("raw_text/Apr18 50 11.csv", index_col=0)
raw____12 = pd.read_csv("raw_text/Apr18 50 12.csv", index_col=0)
raw____13 = pd.read_csv("raw_text/Apr18 50 13.csv", index_col=0)
raw____14 = pd.read_csv("raw_text/Apr18 50 14.csv", index_col=0)
raw____15 = pd.read_csv("raw_text/Apr18 50 15.csv", index_col=0)

raw_____1 = pd.read_csv("raw_text/Apr21 50 1.csv", index_col=0)
raw_____2 = pd.read_csv("raw_text/Apr21 50 2.csv", index_col=0)
raw_____3 = pd.read_csv("raw_text/Apr21 50 3.csv", index_col=0)
raw_____4 = pd.read_csv("raw_text/Apr21 50 4.csv", index_col=0)
raw_____5 = pd.read_csv("raw_text/Apr21 50 5.csv", index_col=0)
raw_____6 = pd.read_csv("raw_text/Apr21 50 6.csv", index_col=0)
raw_____7 = pd.read_csv("raw_text/Apr21 50 7.csv", index_col=0)
raw_____8 = pd.read_csv("raw_text/Apr21 50 8.csv", index_col=0)
raw_____9 = pd.read_csv("raw_text/Apr21 50 9.csv", index_col=0)
raw_____10 = pd.read_csv("raw_text/Apr21 50 10.csv", index_col=0)
raw_____11 = pd.read_csv("raw_text/Apr21 50 11.csv", index_col=0)
raw_____12 = pd.read_csv("raw_text/Apr21 50 12.csv", index_col=0)
raw_____13 = pd.read_csv("raw_text/Apr21 50 13.csv", index_col=0)
raw_____14 = pd.read_csv("raw_text/Apr21 50 14.csv", index_col=0)
raw_____15 = pd.read_csv("raw_text/Apr21 50 15.csv", index_col=0)

raw______1 = pd.read_csv("raw_text/Apr23 50 1.csv", index_col=0)
raw______2 = pd.read_csv("raw_text/Apr23 50 2.csv", index_col=0)
raw______3 = pd.read_csv("raw_text/Apr23 50 3.csv", index_col=0)
raw______4 = pd.read_csv("raw_text/Apr23 50 4.csv", index_col=0)
raw______5 = pd.read_csv("raw_text/Apr23 50 5.csv", index_col=0)
raw______6 = pd.read_csv("raw_text/Apr23 50 6.csv", index_col=0)
raw______7 = pd.read_csv("raw_text/Apr23 50 7.csv", index_col=0)
raw______8 = pd.read_csv("raw_text/Apr23 50 8.csv", index_col=0)
raw______9 = pd.read_csv("raw_text/Apr23 50 9.csv", index_col=0)
raw______10 = pd.read_csv("raw_text/Apr23 50 10.csv", index_col=0)
raw______11 = pd.read_csv("raw_text/Apr23 50 11.csv", index_col=0)
raw______12 = pd.read_csv("raw_text/Apr23 50 12.csv", index_col=0)
raw______13 = pd.read_csv("raw_text/Apr23 50 13.csv", index_col=0)
raw______14 = pd.read_csv("raw_text/Apr23 50 14.csv", index_col=0)
raw______15 = pd.read_csv("raw_text/Apr23 50 15.csv", index_col=0)

raw_______1 = pd.read_csv("raw_text/Apr8 50 1.csv", index_col=0)
raw_______2 = pd.read_csv("raw_text/Apr8 50 2.csv", index_col=0)
raw_______3 = pd.read_csv("raw_text/Apr8 50 3.csv", index_col=0)
raw_______4 = pd.read_csv("raw_text/Apr8 50 4.csv", index_col=0)
raw_______5 = pd.read_csv("raw_text/Apr8 50 5.csv", index_col=0)
raw_______6 = pd.read_csv("raw_text/Apr8 50 6.csv", index_col=0)
raw_______7 = pd.read_csv("raw_text/Apr8 50 7.csv", index_col=0)
raw_______8 = pd.read_csv("raw_text/Apr8 50 8.csv", index_col=0)
raw_______9 = pd.read_csv("raw_text/Apr8 50 9.csv", index_col=0)
raw_______10 = pd.read_csv("raw_text/Apr8 50 10.csv", index_col=0)
raw_______11 = pd.read_csv("raw_text/Apr8 50 11.csv", index_col=0)
raw_______12 = pd.read_csv("raw_text/Apr8 50 12.csv", index_col=0)
raw_______13 = pd.read_csv("raw_text/Apr8 50 13.csv", index_col=0)
raw_______14 = pd.read_csv("raw_text/Apr8 50 14.csv", index_col=0)
raw_______15 = pd.read_csv("raw_text/Apr8 50 15.csv", index_col=0)

raw________1 = pd.read_csv("raw_text/Apr6 50 1.csv", index_col=0)
raw________2 = pd.read_csv("raw_text/Apr6 50 2.csv", index_col=0)
raw________3 = pd.read_csv("raw_text/Apr6 50 3.csv", index_col=0)
raw________4 = pd.read_csv("raw_text/Apr6 50 4.csv", index_col=0)
raw________5 = pd.read_csv("raw_text/Apr6 50 5.csv", index_col=0)
raw________6 = pd.read_csv("raw_text/Apr6 50 6.csv", index_col=0)
raw________7 = pd.read_csv("raw_text/Apr6 50 7.csv", index_col=0)
raw________8 = pd.read_csv("raw_text/Apr6 50 8.csv", index_col=0)
raw________9 = pd.read_csv("raw_text/Apr6 50 9.csv", index_col=0)
raw________10 = pd.read_csv("raw_text/Apr6 50 10.csv", index_col=0)
raw________11 = pd.read_csv("raw_text/Apr6 50 11.csv", index_col=0)
raw________12 = pd.read_csv("raw_text/Apr6 50 12.csv", index_col=0)
raw________13 = pd.read_csv("raw_text/Apr6 50 13.csv", index_col=0)
raw________14 = pd.read_csv("raw_text/Apr6 50 14.csv", index_col=0)
raw________15 = pd.read_csv("raw_text/Apr6 50 15.csv", index_col=0)

# %%
raw__1
# Out:
#                               Blue Moon is similar to  \
# 0    the Moon in appearance. However, it is more d...
# 1    the moon of the same name, but it's not as la...
# 2    the original, but in this case the protagonis...
# 3    the Moon in this regard. The Moon is the cent...
# 4    the previous game in that it is a puzzle game...
# 5    the other two, but it has a higher chance of ...
# 6    the original, but there are some notable diff...
# 7    the old-fashioned game of telephone, where yo...
# 8    the Moon in that it has a bright surface and ...
# 9    the "traditional" moon, with a larger diamete...
# 10   the "Frozen" films. It's a good movie, but it...
# 11   the original, but the sky is white and the mo...
# 12   the Moon, but it has a different color and is...
# 13   the Moon in that it is the second moon in the...
# 14   a typical red moon. It's usually bright and r...
# 15   Blood Moon, but requires a lot more effort in...
# ...

# %%
def process_responses(all_text,keywords,filename):
    frqs = {}
    for prompt in all_text.columns:
        frqs[prompt] = {}
        series = all_text[prompt].str.split("<|endoftext|>", expand=True)[0]
        for brand in keywords:
            cnt = pd.Series(np.zeros_like(series))
            for alias in brand:
                cnt = cnt | series.str.contains('\\b' + alias + '(?:[^A-z]|\\b)', case=False)
            frqs[prompt][brand[0]] = cnt.sum()
    return pd.DataFrame(frqs)

# %%
brands = [
    ["Bud Light", "budlight"],
    ["Coors Light", "coors"],
    ["Budweiser", "bud", "budwiser"],
    ["Corona Extra", "corona"],
    ["Guinness"],
    ["Heineken", "heineken light"],
    ["Stella Artois"],
    ["Blue Moon"],
    ["Pabst Blue Ribbon", "PBR"],
    ["Miller High Life"],
    ["Sam Adams", "Samuel Adams"],
    ["Dos Equis"],
    ["Michelob Ultra", "michelob light"],
    ["Rolling Rock"],
    ["Red Stripe"],
    ["Miller Lite"],
    ["Pilsner Urquell", "pilsner"],
    ["Sierra Nevada Brewing", "Sierra Nevada"]
]

# %%
print(1)
f1 = process_responses(raw1, brands, "")
f2 = process_responses(raw2, brands, "")
f3 = process_responses(raw3, brands, "")
f4 = process_responses(raw4, brands, "")
f5 = process_responses(raw5, brands, "")
f6 = process_responses(raw6, brands, "")
f7 = process_responses(raw7, brands, "")
f8 = process_responses(raw8, brands, "")
f9 = process_responses(raw9, brands, "")
f10 = process_responses(raw10, brands, "")
f11 = process_responses(raw11, brands, "")
f12 = process_responses(raw12, brands, "")
f13 = process_responses(raw13, brands, "")
f14 = process_responses(raw14, brands, "")
f15 = process_responses(raw15, brands, "")

print(2)
f_1 = process_responses(raw_1, brands, "")
f_2 = process_responses(raw_2, brands, "")
f_3 = process_responses(raw_3, brands, "")
f_4 = process_responses(raw_4, brands, "")
f_5 = process_responses(raw_5, brands, "")
f_6 = process_responses(raw_6, brands, "")
f_7 = process_responses(raw_7, brands, "")
f_8 = process_responses(raw_8, brands, "")
f_9 = process_responses(raw_9, brands, "")
f_10 = process_responses(raw_10, brands, "")
f_11 = process_responses(raw_11, brands, "")
f_12 = process_responses(raw_12, brands, "")
f_13 = process_responses(raw_13, brands, "")
f_14 = process_responses(raw_14, brands, "")
f_15 = process_responses(raw_15, brands, "")

print(3)
f__1 = process_responses(raw__1, brands, "")
f__2 = process_responses(raw__2, brands, "")
f__3 = process_responses(raw__3, brands, "")
f__4 = process_responses(raw__4, brands, "")
f__5 = process_responses(raw__5, brands, "")
f__6 = process_responses(raw__6, brands, "")
f__7 = process_responses(raw__7, brands, "")
f__8 = process_responses(raw__8, brands, "")
f__9 = process_responses(raw__9, brands, "")
f__10 = process_responses(raw__10, brands, "")
f__11 = process_responses(raw__11, brands, "")
f__12 = process_responses(raw__12, brands, "")
f__13 = process_responses(raw__13, brands, "")
f__14 = process_responses(raw__14, brands, "")
f__15 = process_responses(raw__15, brands, "")

print(4)
f___1 = process_responses(raw___1, brands, "")
f___2 = process_responses(raw___2, brands, "")
f___3 = process_responses(raw___3, brands, "")
f___4 = process_responses(raw___4, brands, "")
f___5 = process_responses(raw___5, brands, "")
f___6 = process_responses(raw___6, brands, "")
f___7 = process_responses(raw___7, brands, "")
f___8 = process_responses(raw___8, brands, "")
f___9 = process_responses(raw___9, brands, "")
f___10 = process_responses(raw___10, brands, "")
f___11 = process_responses(raw___11, brands, "")
f___12 = process_responses(raw___12, brands, "")
f___13 = process_responses(raw___13, brands, "")
f___14 = process_responses(raw___14, brands, "")
f___15 = process_responses(raw___15, brands, "")

print(5)
f____1 = process_responses(raw____1, brands, "")
f____2 = process_responses(raw____2, brands, "")
f____3 = process_responses(raw____3, brands, "")
f____4 = process_responses(raw____4, brands, "")
f____5 = process_responses(raw____5, brands, "")
f____6 = process_responses(raw____6, brands, "")
f____7 = process_responses(raw____7, brands, "")
f____8 = process_responses(raw____8, brands, "")
f____9 = process_responses(raw____9, brands, "")
f____10 = process_responses(raw____10, brands, "")
f____11 = process_responses(raw____11, brands, "")
f____12 = process_responses(raw____12, brands, "")
f____13 = process_responses(raw____13, brands, "")
f____14 = process_responses(raw____14, brands, "")
f____15 = process_responses(raw____15, brands, "")

print(6)
f_____1 = process_responses(raw_____1, brands, "")
f_____2 = process_responses(raw_____2, brands, "")
f_____3 = process_responses(raw_____3, brands, "")
f_____4 = process_responses(raw_____4, brands, "")
f_____5 = process_responses(raw_____5, brands, "")
f_____6 = process_responses(raw_____6, brands, "")
f_____7 = process_responses(raw_____7, brands, "")
f_____8 = process_responses(raw_____8, brands, "")
f_____9 = process_responses(raw_____9, brands, "")
f_____10 = process_responses(raw_____10, brands, "")
f_____11 = process_responses(raw_____11, brands, "")
f_____12 = process_responses(raw_____12, brands, "")
f_____13 = process_responses(raw_____13, brands, "")
f_____14 = process_responses(raw_____14, brands, "")
f_____15 = process_responses(raw_____15, brands, "")

print(7)
f______1 = process_responses(raw______1, brands, "")
f______2 = process_responses(raw______2, brands, "")
f______3 = process_responses(raw______3, brands, "")
f______4 = process_responses(raw______4, brands, "")
f______5 = process_responses(raw______5, brands, "")
f______6 = process_responses(raw______6, brands, "")
f______7 = process_responses(raw______7, brands, "")
f______8 = process_responses(raw______8, brands, "")
f______9 = process_responses(raw______9, brands, "")
f______10 = process_responses(raw______10, brands, "")
f______11 = process_responses(raw______11, brands, "")
f______12 = process_responses(raw______12, brands, "")
f______13 = process_responses(raw______13, brands, "")
f______14 = process_responses(raw______14, brands, "")
f______15 = process_responses(raw______15, brands, "")

print(8)
f_______1 = process_responses(raw_______1, brands, "")
f_______2 = process_responses(raw_______2, brands, "")
f_______3 = process_responses(raw_______3, brands, "")
f_______4 = process_responses(raw_______4, brands, "")
f_______5 = process_responses(raw_______5, brands, "")
f_______6 = process_responses(raw_______6, brands, "")
f_______7 = process_responses(raw_______7, brands, "")
f_______8 = process_responses(raw_______8, brands, "")
f_______9 = process_responses(raw_______9, brands, "")
f_______10 = process_responses(raw_______10, brands, "")
f_______11 = process_responses(raw_______11, brands, "")
f_______12 = process_responses(raw_______12, brands, "")
f_______13 = process_responses(raw_______13, brands, "")
f_______14 = process_responses(raw_______14, brands, "")
f_______15 = process_responses(raw_______15, brands, "")

print(9)
f________1 = process_responses(raw________1, brands, "")
f________2 = process_responses(raw________2, brands, "")
f________3 = process_responses(raw________3, brands, "")
f________4 = process_responses(raw________4, brands, "")
f________5 = process_responses(raw________5, brands, "")
f________6 = process_responses(raw________6, brands, "")
f________7 = process_responses(raw________7, brands, "")
f________8 = process_responses(raw________8, brands, "")
f________9 = process_responses(raw________9, brands, "")
f________10 = process_responses(raw________10, brands, "")
f________11 = process_responses(raw________11, brands, "")
f________12 = process_responses(raw________12, brands, "")
f________13 = process_responses(raw________13, brands, "")
f________14 = process_responses(raw________14, brands, "")
f________15 = process_responses(raw________15, brands, "")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
joined = f1+f2+f3+f4+f5+f6+f7+f8+f9+f10+f11+f12+f13+f14+f15
joined += f_1+f_2+f_3+f_4+f_5+f_6+f_7+f_8+f_9+f_10+f_11+f_12+f_13+f_14+f_15
joined += f__1+f__2+f__3+f__4+f__5+f__6+f__7+f__8+f__9+f__10+f__11+f__12+f__13+f__14+f__15
joined += f___1+f___2+f___3+f___4+f___5+f___6+f___7+f___8+f___9+f___10+f___11+f___12+f___13+f___14+f___15
joined += f____1+f____2+f____3+f____4+f____5+f____6+f____7+f____8+f____9+f____10+f____11+f____12+f____13+f____14+f____15
joined += f_____1+f_____2+f_____3+f_____4+f_____5+f_____6+f_____7+f_____8+f_____9+f_____10+f_____11+f_____12+f_____13+f_____14+f_____15
joined += f______1+f______2+f______3+f______4+f______5+f______6+f______7+f______8+f______9+f______10+f______11+f______12+f______13+f______14+f______15
joined += f_______1+f_______2+f_______3+f_______4+f_______5+f_______6+f_______7+f_______8+f_______9+f_______10+f_______11+f_______12+f_______13+f_______14+f_______15
joined += f________1+f________2+f________3+f________4+f________5+f________6+f________7+f________8+f________9+f________10+f________11+f________12+f________13+f________14+f________15

# %%
joined
# Out:
#                        Blue Moon is similar to  Bud Light is similar to  \
# Bud Light                                    0                     6384
# Coors Light                                  0                       27
# Budweiser                                    1                     6386
# Corona Extra                                17                       46
# Guinness                                     1                        9
# Heineken                                     0                        3
# Stella Artois                                0                        7
# Blue Moon                                  342                       28
# Pabst Blue Ribbon                            0                        8
# Miller High Life                             0                        0
# Sam Adams                                    0                        2
# Dos Equis                                    0                        0
# ...

# %%
joined.to_csv("freqs/j May3 6750.csv")

# %%
9*750
# Out:
# 6750
